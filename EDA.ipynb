# %%
import pandas as pd
df=pd.read_csv('Raw data_magaya/Maintenance/Carrier List.csv')
df.head()
# Out:
#             Name  Phone  Mobile Phone Email  Fax  Website  Account Number  \
# 0      JE FORTIN    NaN           NaN   NaN  NaN      NaN             NaN
# 1  Transport LFL    NaN           NaN   NaN  NaN      NaN             NaN
# 2  DID Logistics    NaN           NaN   NaN  NaN      NaN             NaN
# 3  Dole Shipping    NaN           NaN   NaN  NaN      NaN             NaN
# 4    Dan Freight    NaN           NaN   NaN  NaN      NaN             NaN
#
#   Contact First Name Contact Last Name  Identification Number  ...  \
# 0                NaN               NaN                    NaN  ...
# 1                NaN               NaN                    NaN  ...
# 2                NaN               NaN                    NaN  ...
# 3                NaN               NaN                    NaN  ...
# 4                NaN               NaN                    NaN  ...
#
#   Payment Terms  IATA Account Number  Airline Prefix  Airline Code  FMC  \
# 0           NaN                  NaN             NaN           NaN  NaN
# 1           NaN                  NaN             NaN           NaN  NaN
# 2           NaN                  NaN             NaN           NaN  NaN
# 3           NaN                  NaN             NaN           NaN  NaN
# 4           NaN                  NaN             NaN           NaN  NaN
#
#    SCAC Code  Available Credit (CAD)  Billing Period Incoterms 1099 Eligible
# 0        NaN                     0.0     Never Apply       NaN            No
# 1        NaN                     0.0     Never Apply       NaN            No
# 2        NaN                     0.0     Never Apply       NaN            No
# 3        NaN                     0.0     Never Apply       NaN            No
# 4        NaN                     0.0     Never Apply       NaN            No
#
# [5 rows x 63 columns]

# %%
df.shape
# Out:
# (51, 63)

# %%
for col in df.columns:
    p = df[col].count()  # counts non-NaN entries
    print(f"{col}: {p}")
# Out:
# Name: 51
# Phone: 1
# Mobile Phone: 1
# Email: 1
# Fax: 0
# Website: 0
# Account Number: 0
# Contact First Name: 1
# Contact Last Name: 1
# Identification Number: 0
# Ident. number type: 51
# System ID: 51
# Street and Number: 0
# City: 0
# State: 0
# Country: 0
# Zip code: 0
# Parent Account: 0
# Carrier Type: 51
# Method code: 51
# Carrier code: 0
# Phone Extension: 1
# IP Address: 51
# Street and Number 1: 0
# Street and Number 2: 0
# Street and Number 3: 0
# Billing Street and Number: 0
# Billing City: 0
# Billing State: 0
# Billing Country: 0
# Billing Zip Code: 0
# Billing Street and Number 1: 0
# Billing Street and Number 2: 0
# Billing Street and Number 3: 0
# Entity ID: 0
# Inactive: 51
# Has Transactions: 51
# Type: 51
# Known Shipper: 51
# Known Shipper Expiration Date: 0
# Notes: 0
# Attachments: 51
# Creation Date: 51
# Division: 0
# Transaction Tracking: 51
# Prepaid: 51
# Date of Birth: 0
# Last Screening Status: 0
# Last Screening Date: 0
# Preferred Currency: 0
# Balance (CAD): 51
# Credit Limit (CAD): 51
# Due Days: 51
# Payment Terms: 0
# IATA Account Number: 0
# Airline Prefix: 0
# Airline Code: 0
# FMC: 0
# SCAC Code: 0
# Available Credit (CAD): 51
# Billing Period: 51
# Incoterms: 0
# 1099 Eligible: 51

# %%
# Find columns with all NaN (or no non-NaN values)
cols_to_drop = [col for col in df.columns if df[col].count() == 0]

# Drop them
df_cleaned = df.drop(columns=cols_to_drop)

print(f"Dropped columns: {cols_to_drop}")
# Out:
# Dropped columns: ['Fax', 'Website', 'Account Number', 'Identification Number', 'Street and Number', 'City', 'State', 'Country', 'Zip code', 'Parent Account', 'Carrier code', 'Street and Number 1', 'Street and Number 2', 'Street and Number 3', 'Billing Street and Number', 'Billing City', 'Billing State', 'Billing Country', 'Billing Zip Code', 'Billing Street and Number 1', 'Billing Street and Number 2', 'Billing Street and Number 3', 'Entity ID', 'Known Shipper Expiration Date', 'Notes', 'Division', 'Date of Birth', 'Last Screening Status', 'Last Screening Date', 'Preferred Currency', 'Payment Terms', 'IATA Account Number', 'Airline Prefix', 'Airline Code', 'FMC', 'SCAC Code', 'Incoterms']

# %%
df_cleaned.shape
# Out:
# (51, 26)

# %%
# collect results in a list of dicts
unique_counts = []

for col in df_cleaned.columns:
    p = df_cleaned[col].nunique()
    unique_counts.append({"column": col, "unique_values": p})

# convert to DataFrame
df_unique_counts = pd.DataFrame(unique_counts)

print(df_unique_counts)
# Out:
# Name: 49 unique values
# Phone: 1 unique values
# Mobile Phone: 1 unique values
# Email: 1 unique values
# Contact First Name: 1 unique values
# Contact Last Name: 1 unique values
# Ident. number type: 1 unique values
# System ID: 1 unique values
# Carrier Type: 2 unique values
# Method code: 2 unique values
# Phone Extension: 1 unique values
# IP Address: 1 unique values
# Inactive: 1 unique values
# Has Transactions: 2 unique values
# Type: 1 unique values
# Known Shipper: 1 unique values
# Attachments: 1 unique values
# Creation Date: 39 unique values
# Transaction Tracking: 1 unique values
# Prepaid: 1 unique values
# Balance (CAD): 1 unique values
# Credit Limit (CAD): 1 unique values
# Due Days: 1 unique values
# Available Credit (CAD): 1 unique values
# Billing Period: 1 unique values
# 1099 Eligible: 1 unique values

# %%
cols_single_value = [col for col in df_cleaned.columns if df_cleaned[col].nunique() == 1]

df_final = df_cleaned.drop(columns=cols_single_value)

print(f"Dropped columns with only one unique value: {cols_single_value}")
# Out:
# Dropped columns with only one unique value: ['Phone', 'Mobile Phone', 'Email', 'Contact First Name', 'Contact Last Name', 'Ident. number type', 'System ID', 'Phone Extension', 'IP Address', 'Inactive', 'Type', 'Known Shipper', 'Attachments', 'Transaction Tracking', 'Prepaid', 'Balance (CAD)', 'Credit Limit (CAD)', 'Due Days', 'Available Credit (CAD)', 'Billing Period', '1099 Eligible']

# %%
df_final
# Out:
#                      Name   Carrier Type Method code Has Transactions  \
# 0               JE FORTIN   Land Carrier      Ground               No
# 1           Transport LFL   Land Carrier      Ground               No
# 2           DID Logistics   Land Carrier      Ground               No
# 3           Dole Shipping  Ocean Carrier       Ocean               No
# 4             Dan Freight   Land Carrier      Ground               No
# 5    Argus Transportation   Land Carrier      Ground               No
# 6                Elevated   Land Carrier      Ground               No
# 7           SFX Transport   Land Carrier      Ground               No
# 8         Ulloa Transport   Land Carrier      Ground               No
# 9        Lealta Transport   Land Carrier      Ground               No
# 10           Traffic Tech   Land Carrier      Ground               No
# 11     Dhanoa Enterprises   Land Carrier      Ground               No
# 12         COSCO Shipping  Ocean Carrier       Ocean               No
# 13  Highway Motor Freight   Land Carrier      Ground               No
# 14                    TQL   Land Carrier      Ground               No
# 15               Megacorp   Land Carrier      Ground               No
# 16                    ONE  Ocean Carrier       Ocean               No
# 17          TMG Logistics   Land Carrier      Ground               No
# 18                    CTX   Land Carrier      Ground               No
# 19               HGC Inc.   Land Carrier      Ground               No
# 20         Gosal Trucking   Land Carrier      Ground               No
# 21                 Maersk  Ocean Carrier       Ocean               No
# 22               RF Cargo   Land Carrier      Ground               No
# 23      Amplify Logistics   Land Carrier      Ground               No
# 24                    ZIM  Ocean Carrier       Ocean               No
# 25          Sherrington T   Land Carrier      Ground               No
# 26                Seafood   Land Carrier      Ground               No
# 27                 Cheema   Land Carrier      Ground               No
# 28            Light Speed   Land Carrier      Ground               No
# 29                Traffix   Land Carrier      Ground               No
# 30                Seafood   Land Carrier      Ground               No
# 31                 Zavitz   Land Carrier      Ground               No
# 32          G. Zavitz Ltd   Land Carrier      Ground               No
# 33                 Musket   Land Carrier      Ground               No
# 34            Xan Systems   Land Carrier      Ground               No
# 35                    ZIM   Land Carrier      Ground              Yes
# 36                    CMA  Ocean Carrier       Ocean               No
# 37                 Harlyn   Land Carrier      Ground               No
# 38                Darragh   Land Carrier      Ground               No
# 39                    MSC  Ocean Carrier       Ocean               No
# 40              Highlight   Land Carrier      Ground               No
# 41                 Zavcor   Land Carrier      Ground               No
# 42                 Fulger   Land Carrier      Ground               No
# 43                Connors   Land Carrier      Ground               No
# 44                 Loadex   Land Carrier      Ground               No
# 45               Seaboard  Ocean Carrier       Ocean               No
# 46                 Savoie   Land Carrier      Ground               No
# 47                Network  Ocean Carrier       Ocean               No
# 48               Scotlynn   Land Carrier      Ground               No
# 49                   Holt   Land Carrier      Ground               No
# 50                Sealand  Ocean Carrier       Ocean               No
#
#    Creation Date
# 0     01/03/2025
# 1     01/02/2025
# 2     12/26/2024
# 3     12/12/2024
# 4     11/15/2024
# 5     07/18/2024
# 6     06/04/2024
# 7     06/03/2024
# 8     05/09/2024
# 9     05/09/2024
# 10    05/08/2024
# 11    05/02/2024
# 12    04/29/2024
# 13    04/19/2024
# 14    03/11/2024
# 15    02/26/2024
# 16    01/31/2024
# 17    10/02/2023
# 18    09/29/2023
# 19    09/22/2023
# 20    09/22/2023
# 21    09/14/2023
# 22    08/01/2023
# 23    05/19/2023
# 24    04/14/2023
# 25    04/06/2023
# 26    02/10/2023
# 27    02/10/2023
# 28    02/10/2023
# 29    11/04/2022
# 30    11/04/2022
# 31    03/23/2022
# 32    03/10/2022
# 33    03/02/2022
# 34    03/01/2022
# 35    01/11/2022
# 36    01/07/2022
# 37    01/06/2022
# 38    12/30/2021
# 39    12/30/2021
# 40    12/22/2021
# 41    12/22/2021
# 42    12/17/2021
# 43    12/17/2021
# 44    12/16/2021
# 45    12/16/2021
# 46    12/15/2021
# 47    12/15/2021
# 48    12/15/2021
# 49    12/13/2021
# 50    12/13/2021

# %%
df_final.to_csv('processing_data/Carrier_dim.csv', index=False)

# %%
import chardet

# Read a sample of bytes from the file
with open('Raw data_magaya/Maintenance/Customer List.csv', 'rb') as f:
    result = chardet.detect(f.read(10000))

print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
df_customer = pd.read_csv('processing_data/cleaned_vendor List.csv', encoding='cp1252')
df_customer.head()
# Out:
#   Account Number                                               Name  \
# 0            NaN  San Diego Refrigerated Services Inc. DBA Harbo...
# 1            NaN                                  DID Logistics INC
# 2            NaN                      Academia de EspaÃ±ol PROBIGUA
# 3            NaN                      DOLE OCEAN CARGO EXPRESS, LLC
# 4            NaN                              EugÃ©nie Dejonckheere
#
#   Street and Number City State Country Zip code           Phone Mobile Phone  \
# 0               NaN  NaN   NaN     NaN      NaN             NaN          NaN
# 1               NaN  NaN   NaN     NaN      NaN             NaN          NaN
# 2               NaN  NaN   NaN     NaN      NaN  (502) 59630640          NaN
# 3               NaN  NaN   NaN     NaN      NaN             NaN          NaN
# 4               NaN  NaN   NaN     NaN      NaN             NaN          NaN
#
#   Email  ... Has Open Transactions Prepaid Preferred Currency Balance (CAD)  \
# 0   NaN  ...                    No     Yes                NaN          0.00
# 1   NaN  ...                    No     Yes                NaN          0.00
# 2   NaN  ...                   Yes     Yes                NaN      2,599.42
# 3   NaN  ...                    No     Yes                NaN          0.00
# 4   NaN  ...                   Yes     Yes                NaN        411.51
#
#   Due Days Payment Terms Billing Period Last Payment Amount (CAD)  \
# 0        0           NaN    Never Apply                  1,227.40
# 1        0           NaN    Never Apply                  5,028.50
# 2        0           NaN    Never Apply                      0.00
# 3        0           NaN    Never Apply                  7,196.10
# 4        0           NaN    Never Apply                      0.00
#
#   Last Payment Date Supplier Invoice?
# 0        01/13/2025                No
# 1        01/09/2025                No
# 2               NaN                No
# 3        01/10/2025                No
# 4               NaN                No
#
# [5 rows x 36 columns]

# %%
for col in df_customer.columns:
    p_c = df_customer[col].nunique()
    print(f"{col}: {p_c} unique values")
# Out:
# Account Number: 36 unique values
# Name: 323 unique values
# Street and Number: 54 unique values
# City: 74 unique values
# State: 33 unique values
# Country: 6 unique values
# Zip code: 81 unique values
# Phone: 60 unique values
# Mobile Phone: 2 unique values
# Email: 29 unique values
# Fax: 4 unique values
# Website: 5 unique values
# Contact First Name: 22 unique values
# Contact Last Name: 8 unique values
# Identification Number: 2 unique values
# Street and Number 1: 54 unique values
# Street and Number 2: 6 unique values
# Billing Street and Number: 40 unique values
# Billing City: 42 unique values
# Billing State: 22 unique values
# Billing Country: 6 unique values
# Billing Zip Code: 36 unique values
# Billing Street and Number 1: 40 unique values
# Billing Street and Number 2: 6 unique values
# Entity ID: 3 unique values
# Has Transactions: 2 unique values
# Has Open Transactions: 2 unique values
# Prepaid: 2 unique values
# Preferred Currency: 2 unique values
# Balance (CAD): 42 unique values
# Due Days: 5 unique values
# Payment Terms: 6 unique values
# Billing Period: 3 unique values
# Last Payment Amount (CAD): 220 unique values
# Last Payment Date: 145 unique values
# Supplier Invoice?: 2 unique values

# %%
df_job =pd.read_csv('Raw data_magaya/Jobs/Job List.csv', encoding='cp1252')
df_job.head()
# Out:
#   Status Number                                    Supplier    Due Date  \
# 0   Open   4637  Marplantis Organic Sustainable Agriculture  01/10/2025
# 1   Open   4634            C.I. AGRICOLAS LAS FLORES S.A.S.  01/08/2025
# 2   Open   4631                                 Latbio S.A.  01/08/2025
# 3   Open   4630                   Hacienda Celia María C.A.  01/08/2025
# 4   Open   4633            C.I. AGRICOLAS LAS FLORES S.A.S.  01/08/2025
#
#   Customer Income    Expense      Profit Customer:Account Number        Date  \
# 0      NaN   0.00  18,337.05  -18,337.05                     NaN  01/10/2025
# 1      NaN   0.00  19,545.98  -19,545.98                     NaN  01/08/2025
# 2      NaN   0.00       0.00        0.00                     NaN  01/08/2025
# 3      NaN   0.00  18,493.31  -18,493.31                     NaN  01/08/2025
# 4      NaN   0.00  19,545.98  -19,545.98                     NaN  01/08/2025
#
#      End Date    Employee  Description  Last Event  Division  Progress (%)  \
# 0  01/10/2025  David Melo          NaN         NaN       NaN            11
# 1  01/08/2025  David Melo          NaN         NaN       NaN            11
# 2  01/08/2025  David Melo          NaN         NaN       NaN            11
# 3  01/08/2025  David Melo          NaN         NaN       NaN            11
# 4  01/08/2025  David Melo          NaN         NaN       NaN            11
#
#    Division:Name Customer:Billing Client  Division:State
# 0            NaN                     NaN             NaN
# 1            NaN                     NaN             NaN
# 2            NaN                     NaN             NaN
# 3            NaN                     NaN             NaN
# 4            NaN                     NaN             NaN

# %%
df_job.shape
# Out:
# (2744, 19)

# %%
import pandas as pd
import os

folder = 'processing_data'

for file in os.listdir(folder):
    if file.endswith('.csv'):
        path = os.path.join(folder, file)
        print(f"\n📄 {file}")
        df = pd.read_csv(path, encoding='cp1252')
        print(df.head(), "\n", "="*40)
# Out:
# 📄 cleaned_Shipment list.csv
#      Status    Type   Waybill Number        Date  \
# 0  Received   Ocean   DOLQSMRD4772WL  01/10/2025
# 1  Received   Ocean   DOLQSMRD4771WL  01/10/2025
# 2  Received  Ground              NaN  01/09/2025
# 3  Received   Ocean  ZIMUGYL00014121  01/08/2025
# 4  Received   Ocean  ZIMUGYL00014176  01/08/2025
#
#                                       Shipper             Consignee  \
# 0            C.I. AGRICOLAS LAS FLORES S.A.S.  United Safety Agents
# 1            C.I. AGRICOLAS LAS FLORES S.A.S.  United Safety Agents
# 2                 Coliman Pacific Corporation       Equifruit, Inc.
# 3  Marplantis Organic Sustainable Agriculture       Equifruit, Inc.
# 4  Marplantis Organic Sustainable Agriculture  United Safety Agents
#
#          Carrier         Origin Port    Destination Port  Pieces  ...  \
# 0  Dole Shipping  Port of Wilmington  Port of Wilmington       1  ...
# 1  Dole Shipping         Santa Marta  Port of Wilmington       1  ...
# 2            CTX             Nogales             Calgary       1  ...
# 3            ZIM           Guayaquil     Port of Halifax       1  ...
# 4            ZIM           Guayaquil        Philadelphia       1  ...
#
#   Spotting Date Package House count On-Carriage by Documentation Cut-off Date  \
# 0    01/10/2025     CNT           0            NaN                        NaN
# 1    01/10/2025     CNT           0            NaN                        NaN
# 2    01/09/2025     CNT           0            NaN                        NaN
# 3    01/08/2025     CNT           0            NaN                        NaN
# 4    01/08/2025     CNT           0            NaN                        NaN
#
#   IT Date Container Tracking ETA Update Terminal x dock date
# 0     NaN                Yes        NaN      NaN         NaN
# 1     NaN                Yes        NaN      NaN         NaN
# 2     NaN                Yes        NaN      NaN         NaN
# 3     NaN                Yes        NaN      NaN         NaN
# 4     NaN                Yes        NaN      NaN         NaN
#
# [5 rows x 85 columns]
#  ========================================
#
# 📄 cleaned_Customer List.csv
#   Account Number                                           Name  \
# 0            NaN  Sprouts Farmers Market - Distribution Centers
# 1     C00006/005                               COSTCO BRANTFORD
# 2            NaN                              Michelle Gubbells
# 3            NaN                                         Maersk
# 4            NaN                     Agence du revenu du Canada
#
#         Street and Number        City State        Country Zip code Phone  \
# 0  5445 West Missouri Ave    Glendale    AZ  United States    85301   NaN
# 1       175 ROY BOULEVARD  BRANTFORD,    ON         Canada  N3R 7K1   NaN
# 2                     NaN         NaN   NaN            NaN      NaN   NaN
# 3                     NaN         NaN   NaN            NaN      NaN   NaN
# 4                     NaN         NaN   NaN            NaN      NaN   NaN
#
#             Email Contact First Name  ... Inactive Has Transactions  \
# 0  AP@Sprouts.com                NaN  ...       No               No
# 1             NaN                NaN  ...       No              Yes
# 2             NaN                NaN  ...       No              Yes
# 3             NaN                NaN  ...       No              Yes
# 4             NaN                NaN  ...       No              Yes
#
#   Creation Date Has Open Transactions Prepaid Balance (CAD) Due Days  \
# 0    01/08/2025                    No      No          0.00       30
# 1    11/15/2024                    No      No          0.00       30
# 2    09/16/2024                    No      No          0.00       30
# 3    08/20/2024                    No      No          0.00       30
# 4    06/10/2024                   Yes      No      2,191.66       30
#
#   Payment Terms Last Payment Amount (CAD) Last Payment Date
# 0        Net 30                      0.00               NaN
# 1        Net 30                  3,360.97        12/09/2024
# 2        Net 30                    385.72        10/28/2024
# 3        Net 30                  1,852.84        08/15/2024
# 4        Net 30                  1,610.73        12/18/2024
#
# [5 rows x 29 columns]
#  ========================================
#
# 📄 cleaned_Forwarding Agent List.csv
#                         Name                            Street and Number  \
# 0  PSA HALIFAX FAIRVIEW COVE                                6708 Bayne St
# 1   DOLE SHIPPING EAST COAST                                1 Hausel Road
# 2    DOLE SHIPPING GULF PORT  Port of Gulfport, 540 30th Avenue West Pier
# 3    DOLE SHIPPING WEST PORT      10Th Av Marine Terminal  1800 Crosby Rd
# 4      JACINTO PORT TERMINAL                 16398 Jacinto Port Boulevard
#
#          City State        Country Zip code  \
# 0     Halifax    NS         Canada  B3K 0H1
# 1  Wilmington    DE  United States    19801
# 2    Gulfport    MS  United States    39501
# 3   San Diego    CA  United States    92101
# 4     Houston    TX  United States    77586
#
#                            Street and Number 1  \
# 0                                6708 Bayne St
# 1                                1 Hausel Road
# 2  Port of Gulfport, 540 30th Avenue West Pier
# 3                      10Th Av Marine Terminal
# 4                 16398 Jacinto Port Boulevard
#
#                      Billing Street and Number Billing City Billing State  \
# 0                                6708 Bayne St      Halifax            NS
# 1   Port of Wilmington, 1870 Burnett Boulevard   Wilmington            NC
# 2  Port of Gulfport, 540 30th Avenue West Pier     Gulfport            MS
# 3      10Th Av Marine Terminal  1800 Crosby Rd    San Diego            CA
# 4                 16398 Jacinto Port Boulevard      Houston            TX
#
#   Billing Country Billing Zip Code  \
# 0          Canada          B3K 0H1
# 1   United States            28401
# 2   United States            39501
# 3   United States            92101
# 4   United States            77586
#
#                    Billing Street and Number 1 Creation Date
# 0                                6708 Bayne St    12/31/2024
# 1   Port of Wilmington, 1870 Burnett Boulevard    12/26/2024
# 2  Port of Gulfport, 540 30th Avenue West Pier    12/16/2024
# 3                      10Th Av Marine Terminal    12/16/2024
# 4                 16398 Jacinto Port Boulevard    09/24/2024
#  ========================================
#
# 📄 cleaned_Vendor list.csv
#   Account Number                                               Name  \
# 0            NaN  San Diego Refrigerated Services Inc. DBA Harbo...
# 1            NaN                                  DID Logistics INC
# 2            NaN                      Academia de EspaÃ±ol PROBIGUA
# 3            NaN                      DOLE OCEAN CARGO EXPRESS, LLC
# 4            NaN                              EugÃ©nie Dejonckheere
#
#   Street and Number City State Country Zip code           Phone Mobile Phone  \
# 0               NaN  NaN   NaN     NaN      NaN             NaN          NaN
# 1               NaN  NaN   NaN     NaN      NaN             NaN          NaN
# 2               NaN  NaN   NaN     NaN      NaN  (502) 59630640          NaN
# 3               NaN  NaN   NaN     NaN      NaN             NaN          NaN
# 4               NaN  NaN   NaN     NaN      NaN             NaN          NaN
#
#   Email  ... Has Open Transactions Prepaid Preferred Currency Balance (CAD)  \
# 0   NaN  ...                    No     Yes                NaN          0.00
# 1   NaN  ...                    No     Yes                NaN          0.00
# 2   NaN  ...                   Yes     Yes                NaN      2,599.42
# 3   NaN  ...                    No     Yes                NaN          0.00
# 4   NaN  ...                   Yes     Yes                NaN        411.51
#
#   Due Days Payment Terms Billing Period Last Payment Amount (CAD)  \
# 0        0           NaN    Never Apply                  1,227.40
# 1        0           NaN    Never Apply                  5,028.50
# 2        0           NaN    Never Apply                      0.00
# 3        0           NaN    Never Apply                  7,196.10
# 4        0           NaN    Never Apply                      0.00
#
#   Last Payment Date Supplier Invoice?
# 0        01/13/2025                No
# 1        01/09/2025                No
# 2               NaN                No
# 3        01/10/2025                No
# 4               NaN                No
#
# [5 rows x 36 columns]
#  ========================================
#
# 📄 cleaned_Carrier_list.csv
#             Name   Carrier Type Method code Has Transactions Creation Date
# 0      JE FORTIN   Land Carrier      Ground               No    01/03/2025
# 1  Transport LFL   Land Carrier      Ground               No    01/02/2025
# 2  DID Logistics   Land Carrier      Ground               No    12/26/2024
# 3  Dole Shipping  Ocean Carrier       Ocean               No    12/12/2024
# 4    Dan Freight   Land Carrier      Ground               No    11/15/2024
#  ========================================
#
# 📄 cleaned_Port List.csv
#     Code       Name        Country Subdivision Air Ocean Rail Road Mail
# 0  USOLS    Nogales  United States         NaN  No    No   No  Yes   No
# 1  USGPT  Gulf Port  United States         NaN  No   Yes   No   No   No
# 2    TXA      Texas  United States          MD  No    No   No  Yes   No
# 3    TEX      Pharr  United States         NaN  No    No   No  Yes   No
# 4    SEA    Seattle  United States         NaN  No    No   No  Yes   No
#  ========================================

# %%
df_purchase= pd.read_csv('Raw data_magaya/purchase orders/Purchase Order List.csv')
df_purchase.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_purchase= pd.read_csv('purchase orders/Purchase Order List.csv')
#       2 df_purchase.head()
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb3 in position 422: invalid start byte

# %%
df_purchase.shape
# Out:
# (977, 75)

# %%
# collect results in a list of dicts
unique_counts = []

for col in df_purchase.columns:
    p = df_purchase[col].nunique()
    unique_counts.append({"column": col, "unique_values": p})

# convert to DataFrame
df_unique_counts = pd.DataFrame(unique_counts)

print(df_unique_counts)
# Out:
#                     column  unique_values
# 0                   Status              6
# 1                   Number            977
# 2                   Seller             11
# 3                  Carrier             13
# 4                   Amount            169
# ..                     ...            ...
# 70  Cornerboards Packaging              3
# 71         Port of Loading              9
# 72       Customs Clearance              2
# 73              Buyer:Name              1
# 74    Buyer:Account Number              0
#
# [75 rows x 2 columns]

# %%
import pandas as pd
df_jobs= pd.read_csv('jobs/Job List.csv', encoding='cp1252')
df_jobs.head()
# Out:
#   Status Number                                    Supplier    Due Date  \
# 0   Open   4637  Marplantis Organic Sustainable Agriculture  01/10/2025
# 1   Open   4634            C.I. AGRICOLAS LAS FLORES S.A.S.  01/08/2025
# 2   Open   4631                                 Latbio S.A.  01/08/2025
# 3   Open   4630                   Hacienda Celia María C.A.  01/08/2025
# 4   Open   4633            C.I. AGRICOLAS LAS FLORES S.A.S.  01/08/2025
#
#   Customer Income    Expense      Profit Customer:Account Number        Date  \
# 0      NaN   0.00  18,337.05  -18,337.05                     NaN  01/10/2025
# 1      NaN   0.00  19,545.98  -19,545.98                     NaN  01/08/2025
# 2      NaN   0.00       0.00        0.00                     NaN  01/08/2025
# 3      NaN   0.00  18,493.31  -18,493.31                     NaN  01/08/2025
# 4      NaN   0.00  19,545.98  -19,545.98                     NaN  01/08/2025
#
#      End Date    Employee  Description  Last Event  Division  Progress (%)  \
# 0  01/10/2025  David Melo          NaN         NaN       NaN            11
# 1  01/08/2025  David Melo          NaN         NaN       NaN            11
# 2  01/08/2025  David Melo          NaN         NaN       NaN            11
# 3  01/08/2025  David Melo          NaN         NaN       NaN            11
# 4  01/08/2025  David Melo          NaN         NaN       NaN            11
#
#    Division:Name Customer:Billing Client  Division:State
# 0            NaN                     NaN             NaN
# 1            NaN                     NaN             NaN
# 2            NaN                     NaN             NaN
# 3            NaN                     NaN             NaN
# 4            NaN                     NaN             NaN

# %%
# collect results in a list of dicts
unique_counts = []

for col in df_jobs.columns:
    p = df_jobs[col].nunique()
    unique_counts.append({"column": col, "unique_values": p})

# convert to DataFrame
df_unique_counts = pd.DataFrame(unique_counts)

print(df_unique_counts)
# Out:
#                      column  unique_values
# 0                    Status              2
# 1                    Number           2739
# 2                  Supplier             14
# 3                  Due Date            922
# 4                  Customer             22
# 5                    Income           1672
# 6                   Expense           2651
# 7                    Profit           2671
# 8   Customer:Account Number             14
# 9                      Date            350
# 10                 End Date            102
# 11                 Employee              8
# 12              Description              0
# 13               Last Event              0
# 14                 Division              0
# 15             Progress (%)             17
# 16            Division:Name              0
# 17  Customer:Billing Client              1
# 18           Division:State              0

# %%
df_jobs.shape
# Out:
# (2744, 19)

# %%
df_jobs_cleaned = pd.read_csv('Cleaned_data/Job_list.csv', encoding='cp1252')
df_jobs_cleaned.head()
# Out:
#   Status Number                                    Supplier    Due Date  \
# 0   Open   4637  Marplantis Organic Sustainable Agriculture  01/10/2025
# 1   Open   4634            C.I. AGRICOLAS LAS FLORES S.A.S.  01/08/2025
# 2   Open   4631                                 Latbio S.A.  01/08/2025
# 3   Open   4630                  Hacienda Celia MarÃ­a C.A.  01/08/2025
# 4   Open   4633            C.I. AGRICOLAS LAS FLORES S.A.S.  01/08/2025
#
#   Customer Income    Expense      Profit Customer:Account Number        Date  \
# 0      NaN   0.00  18,337.05  -18,337.05                     NaN  01/10/2025
# 1      NaN   0.00  19,545.98  -19,545.98                     NaN  01/08/2025
# 2      NaN   0.00       0.00        0.00                     NaN  01/08/2025
# 3      NaN   0.00  18,493.31  -18,493.31                     NaN  01/08/2025
# 4      NaN   0.00  19,545.98  -19,545.98                     NaN  01/08/2025
#
#      End Date    Employee  Progress (%)
# 0  01/10/2025  David Melo            11
# 1  01/08/2025  David Melo            11
# 2  01/08/2025  David Melo            11
# 3  01/08/2025  David Melo            11
# 4  01/08/2025  David Melo            11

# %%
df_jobs_cleaned.shape

# %%
df_jobs_cleaned.columns
# Out:
# Index(['Status', 'Number', 'Supplier', 'Due Date', 'Customer', 'Income',
#        'Expense', 'Profit', 'Customer:Account Number', 'Date', 'End Date',
#        'Employee', 'Progress (%)'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example: assume your cleaned dataframe is already loaded
# df_jobs_cleaned = ...

# 1️⃣ Calculate NaN percentage in 'Customer'
nan_percentage = df_jobs_cleaned['Customer'].isna().mean() * 100
print(f"NaN Percentage in 'Customer': {nan_percentage:.2f}%")

# 2️⃣ Plot histogram of 'Customer'
plt.figure(figsize=(8,5))
df_jobs_cleaned['Customer'].value_counts(dropna=False).plot(kind='bar')
plt.title("Histogram of Customer Column")
plt.xlabel("Customer")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# NaN Percentage in 'Customer': 41.00%

# %%
# jobs list customer is missing, try to filling in or at least figure out where the processing_data could be found
df_customer = pd.read_csv('Cleaned_data/Maintenance_Customer List.csv', encoding='cp1252')
df_customer.head()
# Out:
#   Account Number                                           Name  \
# 0            NaN  Sprouts Farmers Market - Distribution Centers
# 1     C00006/005                               COSTCO BRANTFORD
# 2            NaN                              Michelle Gubbells
# 3            NaN                                         Maersk
# 4            NaN                     Agence du revenu du Canada
#
#         Street and Number        City State        Country Zip code Phone  \
# 0  5445 West Missouri Ave    Glendale    AZ  United States    85301   NaN
# 1       175 ROY BOULEVARD  BRANTFORD,    ON         Canada  N3R 7K1   NaN
# 2                     NaN         NaN   NaN            NaN      NaN   NaN
# 3                     NaN         NaN   NaN            NaN      NaN   NaN
# 4                     NaN         NaN   NaN            NaN      NaN   NaN
#
#             Email Contact First Name  ... Inactive Has Transactions  \
# 0  AP@Sprouts.com                NaN  ...       No               No
# 1             NaN                NaN  ...       No              Yes
# 2             NaN                NaN  ...       No              Yes
# 3             NaN                NaN  ...       No              Yes
# 4             NaN                NaN  ...       No              Yes
#
#   Creation Date Has Open Transactions Prepaid Balance (CAD) Due Days  \
# 0    01/08/2025                    No      No          0.00       30
# 1    11/15/2024                    No      No          0.00       30
# 2    09/16/2024                    No      No          0.00       30
# 3    08/20/2024                    No      No          0.00       30
# 4    06/10/2024                   Yes      No      2,191.66       30
#
#   Payment Terms Last Payment Amount (CAD) Last Payment Date
# 0        Net 30                      0.00               NaN
# 1        Net 30                  3,360.97        12/09/2024
# 2        Net 30                    385.72        10/28/2024
# 3        Net 30                  1,852.84        08/15/2024
# 4        Net 30                  1,610.73        12/18/2024
#
# [5 rows x 29 columns]

# %%
df_customer['Name'].unique()
# Out:
# array(['Sprouts Farmers Market - Distribution Centers',
#        'COSTCO BRANTFORD', 'Michelle Gubbells', 'Maersk',
#        'Agence du revenu du Canada', 'Revenu QuÃ©bec', 'Costco Canada',
#        'Holt Cargo Systems', 'Charlies Los Angeles', 'Equifruit',
#        'Charlies Seattle', 'Wal-Mart',
#        'Fairtrade Labelling Organizations Inter. e.V.', 'Latbio S.A.',
#        'Four Seasons', 'Costco Etobicoke', 'Sobeys Winnipeg',
#        'East Coast', 'Moisson MontrÃ©al inc.', 'Top Banana',
#        'Krown Produce  Fresh At Its Bestâ„¢', 'Costco US/East',
#        'Costco Calgary', 'Gambles', 'Costco London', 'Sobeys Vancouver',
#        'York University', 'Sobeys Calgary', 'Split Sobeys BCH + WBY',
#        'Sobeys Quebec City', 'DegranprÃ© Chait', 'Gloucester', 'Musket',
#        'Connors Transfer Limited', 'Costco Varennes', 'Loadex',
#        'Sobeys Whitby', 'RÃ©seaux Plein Air Drummond Inc',
#        'ITradeNetwork', 'SPLIT:  BCH + Cola', 'MIXED Chiov Gambles',
#        'Scotlynn', 'Chiovitti Banana Co., Ltd', 'Acc Migration',
#        'Pertes USD', 'Vegfresh Inc.', 'Sobeys BCH', 'Second Harvest',
#        'GO FRESH', 'Fresh Direct Produce', 'Courchesne Larose',
#        'Costco Vaughan Wet', 'CANADAWIDE FRUIT WHOLESALERS',
#        'POS Sales Customer', 'Online Sales Customer'], dtype=object)

# %%
df_vendor = pd.read_csv('Cleaned_data/Vendor.csv', encoding='cp1252')
df_vendor.head()
# Out:
#   Account Number                                               Name  \
# 0            NaN  San Diego Refrigerated Services Inc. DBA Harbo...
# 1            NaN                                  DID Logistics INC
# 2            NaN                      Academia de EspaÃ±ol PROBIGUA
# 3            NaN                      DOLE OCEAN CARGO EXPRESS, LLC
# 4            NaN                              EugÃ©nie Dejonckheere
#
#   Street and Number City State Country Zip code           Phone Mobile Phone  \
# 0               NaN  NaN   NaN     NaN      NaN             NaN          NaN
# 1               NaN  NaN   NaN     NaN      NaN             NaN          NaN
# 2               NaN  NaN   NaN     NaN      NaN  (502) 59630640          NaN
# 3               NaN  NaN   NaN     NaN      NaN             NaN          NaN
# 4               NaN  NaN   NaN     NaN      NaN             NaN          NaN
#
#   Email  ... Has Open Transactions Prepaid Preferred Currency Balance (CAD)  \
# 0   NaN  ...                    No     Yes                NaN          0.00
# 1   NaN  ...                    No     Yes                NaN          0.00
# 2   NaN  ...                   Yes     Yes                NaN      2,599.42
# 3   NaN  ...                    No     Yes                NaN          0.00
# 4   NaN  ...                   Yes     Yes                NaN        411.51
#
#   Due Days Payment Terms Billing Period Last Payment Amount (CAD)  \
# 0        0           NaN    Never Apply                  1,227.40
# 1        0           NaN    Never Apply                  5,028.50
# 2        0           NaN    Never Apply                      0.00
# 3        0           NaN    Never Apply                  7,196.10
# 4        0           NaN    Never Apply                      0.00
#
#   Last Payment Date Supplier Invoice?
# 0        01/13/2025                No
# 1        01/09/2025                No
# 2               NaN                No
# 3        01/10/2025                No
# 4               NaN                No
#
# [5 rows x 36 columns]

# %%
df_vendor['Name'].unique()
# Out:
# array(['San Diego Refrigerated Services Inc. DBA Harborside Operating Account',
#        'DID Logistics INC', 'Academia de EspaÃ±ol PROBIGUA',
#        'DOLE OCEAN CARGO EXPRESS, LLC', 'EugÃ©nie Dejonckheere',
#        "Alliance pour l'engagement jeunesse | alliance-jeunesse.org",
#        'Cari St-Laurent', 'Immigration Lamonde inc.',
#        'Phoenix Media Network Inc.', 'York U',
#        'Calgary Produce Marketing Association', 'OREPRODU SA',
#        'UniversitÃ© McGill', 'C.I. LA SAMARIA S.A.S', 'Visa Banque Royal',
#        'Association Inti', 'Ashley McPhee', 'Nathalie Charron',
#        'Gaylord Opryland Resort and Convention Center',
#        'Ordre des Agronomes du QuÃ©bec', 'CMA CGM',
#        'LTB Magazine (SociÃ©tÃ© ParallÃ¨le)',
#        'Karene-Isabelle Jean-Baptiste', 'Pelletier & Cie avocats inc.',
#        'Blue Horseshoe', 'CMA CGM (CANADA) INC', 'helloDARWIN',
#        'Pro-Cert Organic Systems Ltd.',
#        "Cathy's Action Packed Inc./Let's Party",
#        "l'Ã‰cole de la Magdeleine",
#        'Carrefour de SolidaritÃ© Internationale',
#        'COSCO SHIPPING Lines (North America) Inc.', 'John Simoulidis',
#        'Circular Materials', 'Vasty Santamaria', 'Fondation Philou',
#        'ASOCIACION DE DESARROLLO SOCIAL CARMITA', 'Forgestik',
#        'TQL Total Quality Logistics', 'Concordia University', 'B Lab',
#        'Top Banana', 'Institut des administrateurs de sociÃ©tÃ©s',
#        'One Ocean Network Express', 'MegaCorp Logistics', 'Oxfam QuÃ©bec',
#        'Lufa Farms Inc.', 'Coralus Promerly Sheeo',
#        'Solutions iTCloud.ca', 'CohnReznick LLP', 'Shelby Dwyer',
#        'Southeast Produce Council Inc', 'Tito Ruben Hidalgo Novillo',
#        'UNE MAMAN VÃ‰GANE', 'Theveganginger', 'Fernanda Gonzalez', 'GES',
#        'Hacienda Celia MarÃ\xada C.A.', 'ONTARIO TECH UNIVERSITY',
#        'Dana Hospitality', 'The Produce News', 'Humber College',
#        'Krown Produce Inc.', 'University of Guelph', 'Tribal Ink',
#        'Mallette S.E.N.C.R.L.', 'Affinity Produce Partners, LLC',
#        'Claudia Ramirez', 'Canadian Tire', 'Scanova',
#        'Eco Entreprises QuÃ©bec', 'Savoie express Inc.',
#        'Short and sweat wellness inc.', 'Costco Wholesale Canada Ltd.',
#        'Pacific Marine Consultants, Inc.', 'Sales Is Not Simple Inc.',
#        'Tive, Inc.', "La corporation du College de l'Assomption",
#        'Christou Global Marketing Services LLC', 'BrandSpirit',
#        'Organic Produce Network, LLC', 'Amplify Logistics', 'RBC Express',
#        'Patrick Kovari', 'Flair', 'Sherrie L. Terry Consulting, LLC',
#        'ANACAPA FRESH LOGISTICS, LLC', 'Fresh Plaza B.V.',
#        'ZIM AMERICAN INTEGRATED SHIPPING SERVICES CO., LLC', 'RF Cargo',
#        'J K Fresh LLC.', 'CMA CGM (AMERICA) LLC', 'Impact XM.',
#        'Chiovitti Canada Co. Ltd', 'Daniel Loggale', 'Luca Falcicchio',
#        'BGL Brokerage Ltd', 'Bon pour toi Inc.',
#        'Canada Border Services Agency',
#        'CALIDAD Y PRODUCTIVIDAD LAS AMERICAS, S.A CPLA', 'DaszkalBolton',
#        'AQDFL', 'Channel Islands Warehouse, Inc.',
#        'Organic Produce Summit', 'Latbio S.A.',
#        'Corporacion promesa el guabo', 'PRIETO EXPORT S.A.', 'Costco.ca',
#        "Lang Students' Association",
#        "Agence canadienne d'inspection des aliments", 'Microsoft',
#        'Amazon.ca', 'Digital Ocean', 'Rexall', 'Yellow Image',
#        'Star Metroland Sbscrp', 'Linguistica360, Inc.',
#        'Canadian Business for Social Responsibility', 'PRIECOR S.A.',
#        'DegrandprÃ© Chait', 'International fresh produce Association',
#        'ASOCIACION DE DESARROLLO SOCIAL UNION', 'Monica Chakcal',
#        'Meltwater', 'Productions Cazabon Inc.', 'Walter Ugalde Almengor',
#        'Feliciaa Richer', 'Traffix, 673753 Ontario Limited DBA Traffix',
#        'Farm Journal', 'Marie Lamare', 'BananaLink', 'NSF International',
#        'Eco friendly choices', 'Environnement Jeunesse',
#        'Segal & Santillo', 'Marplantis Organic Sustainable Agriculture',
#        'Gerifruit Organic Fruit',
#        'Packer Avenue (Greenwich Terminals LLC)', 'United Safety Agents',
#        'Surgesa S.A.', 'RightSleeve', 'Blue Book Services, Inc.', 'Golay',
#        'EntreChefs PME', 'Kristian G Grafing', 'David Melo',
#        'Corporation Inno-Centre du Quebec', 'Tik Tok',
#        'UniversitÃ© de Sherbrooke', 'PH Explora', 'CostcoMarkhamEast',
#        'Naomi Bendayan', 'Magasin du Monde du CollÃ¨ge de lâ€™Assomption',
#        'Code Serigraphie & Broderie', 'Kiosk Dimensions inc.', 'SPS',
#        'Etik & co', 'Loadex Inc.',
#        'BGY, RÃ©munÃ©ration globale et avantages sociaux',
#        'Greig Gilbert', 'VECONINTER USA, LLC.',
#        'Association VÃ©gÃ©tarienne de MontrÃ©al',
#        "Association des anciennes et anciens de l'ITA", 'Costco_Empties',
#        'Universidad de los Andes', 'Seaboard Marine Ltd.',
#        'PSA Penn Terminals', 'Costco Finds Canada',
#        'Gloucester Terminals LLC', 'Costco Everything', 'Zvi Rafilovich',
#        'Zoom Video Communications Inc.', 'Wishingstep',
#        'William Grandmont', 'VOLO ATHLETICS INC.', 'Twitter Inc', 'TUX',
#        'Transcontinental Printing 2005 G.P.', 'Traffic Tech Inc. CA',
#        'Traffic Tech Inc.', 'TI Group Inc.',
#        'The Ontario Produce Marketing Association',
#        'The Fair Trade Show Inc.', 'TFI TRANSPORT 3 LP',
#        'Ten Acre Marketing', 'Tedy', 'Sure Fresh SRL',
#        'Solertia Avantages Sociaux inc.', 'Sobeys', 'Smart & Biggar LLP',
#        'SignNation Inc.', 'SEAPORT', 'Maersk',
#        'Scotlynn Commodities, Inc.', 'Sarah Martin', 'Sarah Lolley',
#        'Sage 50cloud Accounting', 'Ronnie Natra Ihilov',
#        'Rock the Bike !', 'Revenu Quebec', 'Reece Van Breda',
#        'Randi Sayer', 'Produce Marketing Association', 'PRAGOR',
#        'Photography by Jeff Murray', 'PFENNINGS ORGANIC VEGETABLES',
#        'Pellerin Potvin Gagnon', 'Pamela Riemenschneider', 'Palmaplast',
#        'Paks Snacks LLC', 'Organic Conference',
#        'Operadora Portuaria Centroamericana', 'Oasis Bags',
#        'Noelle Le Conte-Good', 'Nishal Vipul Shah', 'Nicoverde S.A.',
#        'MUSKET TRANSPORT LTD', 'MTMX Logistics', 'MSC', 'MOL', 'MNP LLP',
#        'MinistÃ¨re du revenu du QuÃ©bec', 'Michelle Gubbels',
#        'Michele Pulichino', 'Melanie Vert', 'Matthew Banks', 'Mastercard',
#        'Maryann Moffitt', 'Mardiempre', 'Manor House Group Limited',
#        'Magaya', 'Madison Hopper', 'Lyndsay Alves', 'Loubna El Wacham',
#        'Longo Brothers Fruit Markets Inc', 'Lisa Sim', 'Linkedin',
#        'Lindsay Walker', 'Linda Labrosse', 'Beneva', 'Consultation M365',
#        'Kingston Fresh', 'Kim Chackal', 'Karyne Manseau', 'Jess Kaluchi',
#        'Jennie Coleman', 'J.O. Alvarez Inc', 'ITradeNetwork', 'IPIC',
#        'Insignia', 'Imprimeries transcontinental Inc.',
#        'Holt Cargo Systems LLC', 'Holosonic', 'Harlyn Transport',
#        'Hamburg Sud', 'GWBR', 'GT INTERMODAL', 'GS1 Canada',
#        'Groupe Export Agroalimentaire', 'Grocery Business Media Inc.',
#        'Greenwich Terminals LLC', 'Green Campus Co-operative',
#        'GEODIS USA inc', 'GDFD2U', 'Gambles', 'Gaida & Steph Inc.',
#        'Gabrielle Carrier', 'Gabriela Montalvo Pereira', 'G lagence',
#        'FrÃ©dÃ©rick Martin', 'Francois Gervais',
#        'Food and Agriculture Organization of the United Nations',
#        'Fernwood Publishing Company Limited', 'FEDEX', 'FE inspection',
#        'Faxinating Solutions Inc', 'Fairtrade Canada inc.', 'Meta',
#        'Expo Manger SantÃ© Inc', 'Execulytics consulting',
#        'TELUS Solutions en santÃ© inc.', 'Element 54 Inc.', 'ASOGUABO',
#        'Ecocert Canada', 'East Coast', 'Desjardins Assurances',
#        'Delaware Avenue Enterprises Inc',
#        'Del Monte Fresh Produce Company', 'Dayton Self Storage',
#        'Courchesne Larose, Ltee',
#        'Corporation de rÃ¨glement des diffÃ©rends dans les fru',
#        'COQUIMBA', 'Communications Grenier inc.',
#        'Coliman Pacific Corporation', 'CNESST', 'CIBIM',
#        'Chic Sophistic Inc.', 'Dayforce', 'CDC Drummond',
#        'Capitol Corporate Services, Inc.',
#        'Canadian Produce Marketing Association',
#        'Canadian Fair Trade Network', 'Canadawide Fruit Wholesalers, Inc',
#        'Canada Post', 'C.I. AGRICOLAS LAS FLORES S.A.S.',
#        'Buy Good. Feel Good', 'Bell mobilitÃ©',
#        'B.B.C Construction (Building Best Condo Inc.)',
#        'HUB International QuÃ©bec limitÃ©e',
#        'Association QuÃ©becoise du Commerce Equitable',
#        'Armutlu & Arapyan Inc.', 'Argus', 'APPBOSA', 'Amandine Hance',
#        'Alan Grant Consulting Inc.', 'AgroFair',
#        'Agricola Fairtrasa S.R.L.', 'Agence du revenu du Canada', 'Adobe',
#        'Association QuÃ©bÃ©coise de la distribution de fruits et lÃ©gumes',
#        '721 LOGISTICS LLC DBA J&K FRESHEAST', 'Belll',
#        'Default Tax Authority'], dtype=object)

# %%
df_carrier = pd.read_csv('Cleaned_data/Carrier_dim.csv', encoding='cp1252')
df_carrier.head()
# Out:
#             Name   Carrier Type Method code Has Transactions Creation Date
# 0      JE FORTIN   Land Carrier      Ground               No    01/03/2025
# 1  Transport LFL   Land Carrier      Ground               No    01/02/2025
# 2  DID Logistics   Land Carrier      Ground               No    12/26/2024
# 3  Dole Shipping  Ocean Carrier       Ocean               No    12/12/2024
# 4    Dan Freight   Land Carrier      Ground               No    11/15/2024

# %%
df_carrier['Name'].unique()
# Out:
# array(['JE FORTIN', 'Transport LFL', 'DID Logistics', 'Dole Shipping',
#        'Dan Freight', 'Argus Transportation', 'Elevated', 'SFX Transport',
#        'Ulloa Transport', 'Lealta Transport', 'Traffic Tech',
#        'Dhanoa Enterprises', 'COSCO Shipping', 'Highway Motor Freight',
#        'TQL', 'Megacorp', 'ONE', 'TMG Logistics', 'CTX', 'HGC Inc.',
#        'Gosal Trucking', 'Maersk', 'RF Cargo', 'Amplify Logistics', 'ZIM',
#        'Sherrington T', 'Seafood', 'Cheema', 'Light Speed', 'Traffix',
#        'Zavitz', 'G. Zavitz Ltd', 'Musket', 'Xan Systems', 'CMA',
#        'Harlyn', 'Darragh', 'MSC', 'Highlight', 'Zavcor', 'Fulger',
#        'Connors', 'Loadex', 'Seaboard', 'Savoie', 'Network', 'Scotlynn',
#        'Holt', 'Sealand'], dtype=object)

# %%
df_carrier['Name'].nunique()
# Out:
# 49

# %%
df_carrier[df_carrier['Name']=="Seafood"]
# Out:
#        Name  Carrier Type Method code Has Transactions Creation Date
# 26  Seafood  Land Carrier      Ground               No    02/10/2023
# 30  Seafood  Land Carrier      Ground               No    11/04/2022

# %%
df_carrier[df_carrier['Carrier Type'] == "Ocean Carrier"]
# Out:
#               Name   Carrier Type Method code Has Transactions Creation Date
# 3    Dole Shipping  Ocean Carrier       Ocean               No    12/12/2024
# 12  COSCO Shipping  Ocean Carrier       Ocean               No    04/29/2024
# 16             ONE  Ocean Carrier       Ocean               No    01/31/2024
# 21          Maersk  Ocean Carrier       Ocean               No    09/14/2023
# 24             ZIM  Ocean Carrier       Ocean               No    04/14/2023
# 36             CMA  Ocean Carrier       Ocean               No    01/07/2022
# 39             MSC  Ocean Carrier       Ocean               No    12/30/2021
# 45        Seaboard  Ocean Carrier       Ocean               No    12/16/2021
# 47         Network  Ocean Carrier       Ocean               No    12/15/2021
# 50         Sealand  Ocean Carrier       Ocean               No    12/13/2021

# %%
df_carrier['Has Transactions'].value_counts()
# Out:
# Has Transactions
# No     50
# Yes     1
# Name: count, dtype: int64

# %%
# 2️⃣ Plot histogram of 'Customer'
plt.figure(figsize=(8,5))
df_carrier['Name'].value_counts(dropna=False).plot(kind='bar')
plt.title("Histogram of Carrier Column")
plt.xlabel("Carrier")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
meta = {
    "table_name": "carrier_dim",
    "description": "Dimension table listing carriers, their type, method, and status.",
    "primary_key": "Name",
    "row_count": len(df_carrier),
    "column_count": df_carrier.shape[1],
    "source": "Operational carrier/vendor system",
    "notes": "Includes both land and ocean carriers; Missing interpretation on 'Has Transactions'(whether active or not), ZIM, Seafood appear twice",
}

data_dict = pd.DataFrame({
    "Column Name": df_carrier.columns,
    "Data Type": [str(df_carrier[col].dtype) for col in df_carrier.columns],
    "Description": ["", "", "", "", ""],  # Fill manually
    "Example Value": [df_carrier[col].dropna().unique()[0] for col in df_carrier.columns]
})

print(meta)
print(data_dict)
# Out:
# {'table_name': 'carrier_dim', 'description': 'Dimension table listing carriers, their type, method, and status.', 'primary_key': 'Name', 'row_count': 51, 'column_count': 5, 'source': 'Operational carrier/vendor system', 'notes': "Includes both land and ocean carriers; Missing interpretation on 'Has Transactions'(whether active or not), ZIM, Seafood appear twice"}
#         Column Name Data Type Description Example Value
# 0              Name    object                 JE FORTIN
# 1      Carrier Type    object              Land Carrier
# 2       Method code    object                    Ground
# 3  Has Transactions    object                        No
# 4     Creation Date    object                01/03/2025

# %%
data_dict.to_csv("carrier_dim_data_dictionary.csv", index=False)

# %%
import json
with open("carrier_dim_metadata.json", "w") as f:
    json.dump(meta, f, indent=4)

# %%
df_port = pd.read_csv('Cleaned_data/Port_list.csv', encoding='cp1252')
df_port.head(10)
# Out:
#     Code          Name        Country Subdivision  Air Ocean Rail Road Mail
# 0  USOLS       Nogales  United States         NaN   No    No   No  Yes   No
# 1  USGPT     Gulf Port  United States         NaN   No   Yes   No   No   No
# 2    TXA         Texas  United States          MD   No    No   No  Yes   No
# 3    TEX         Pharr  United States         NaN   No    No   No  Yes   No
# 4    SEA       Seattle  United States         NaN   No    No   No  Yes   No
# 5    PHL  Philadelphia  United States          PA  Yes   Yes   No   No  Yes
# 6    PHA         Pharr  United States         NaN   No    No   No  Yes   No
# 7     NY      New York  United States         NaN   No    No   No   No   No
# 8    NTD  Port Hueneme  United States          CA  Yes   Yes  Yes  Yes   No
# 9  NOGAL       Nogales  United States         NaN   No    No   No   No   No

# %%
df_port['Country'].unique()
# Out:
# array(['United States', 'Peru', 'Nicaragua', 'Ecuador', 'Colombia',
#        'Canada'], dtype=object)

# %%
df_port.shape
# Out:
# (30, 9)

# %%
df_purchase = pd.read_csv('Raw data_magaya/purchase orders/purchase_order_list.csv', encoding='cp1252')
df_purchase.head(10)
# Out:
#   Status  Number                                      Seller         Carrier  \
# 0   Open    4637  Marplantis Organic Sustainable Agriculture          Maersk
# 1   Open    4634            C.I. AGRICOLAS LAS FLORES S.A.S.   Dole Shipping
# 2   Open    4631                                 Latbio S.A.          Maersk
# 3   Open    4630                   Hacienda Celia María C.A.          Maersk
# 4   Open    4633            C.I. AGRICOLAS LAS FLORES S.A.S.        Seaboard
# 5   Open    4632                                    ASOGUABO          Maersk
# 6   Open    4626                                    ASOGUABO  COSCO Shipping
# 7   Open    4625                                    ASOGUABO  COSCO Shipping
# 8   Open    4635                                    ASOGUABO   Dole Shipping
# 9   Open    4629                                    ASOGUABO          Maersk
#
#          Amount  Quantity Invoiced Departure Date Arrival Date  \
# 0  USD 12690.00       900       No        1/18/25       2/3/25
# 1  USD 13536.00       960       No        1/25/25       2/2/25
# 2      USD 0.00       900       No        1/18/25       2/3/25
# 3  USD 12807.00       900       No        1/18/25       2/3/25
# 4  USD 13536.00       960       No        1/25/25       2/4/25
# 5  USD 13344.00       960       No        1/18/25       2/3/25
# 6  USD 13344.00       960       No        1/18/25      1/29/25
# 7  USD 12645.00       900       No        1/18/25      1/29/25
# 8  USD 12645.00       900       No        1/17/25      1/26/25
# 9  USD 12645.00       900       No        1/18/25       2/3/25
#
#   Port of Arrival  ...  Job:Due Date Temperature Recorder Band Packaging  \
# 0    Philadelphia  ...       1/10/25                  NaN            NaN
# 1      Wilmington  ...        1/8/25                  NaN            NaN
# 2    Philadelphia  ...        1/8/25                  NaN            NaN
# 3    Philadelphia  ...        1/8/25                  NaN            NaN
# 4    Philadelphia  ...        1/8/25                  NaN            NaN
# 5    Philadelphia  ...        1/8/25                  NaN            NaN
# 6    Philadelphia  ...        1/8/25                  NaN            NaN
# 7    Philadelphia  ...        1/8/25                  NaN            NaN
# 8       San Diego  ...        1/8/25                  NaN            NaN
# 9    Philadelphia  ...        1/8/25                  NaN            NaN
#
#   Sticker Packaging Cases Packaging Cornerboards Packaging  Port of Loading  \
# 0               NaN             NaN               Plastico   Puerto Bolivar
# 1               NaN             NaN                 Carton      Santa Marta
# 2               NaN             NaN               Plastico   Puerto Bolivar
# 3               NaN             NaN               Plastico   Puerto Bolivar
# 4               NaN             NaN                 Carton      Santa Marta
# 5               NaN             NaN     Plastico reciclado   Puerto Bolivar
# 6               NaN             NaN     Plastico reciclado        Guayaquil
# 7               NaN             NaN               Plastico        Guayaquil
# 8               NaN             NaN     Plastico reciclado        Guayaquil
# 9               NaN             NaN     Plastico reciclado   Puerto Bolivar
#
#    Customs Clearance       Buyer:Name Buyer:Account Number
# 0                NaN  Equifruit, Inc.                  NaN
# 1                NaN  Equifruit, Inc.                  NaN
# 2                NaN  Equifruit, Inc.                  NaN
# 3                NaN  Equifruit, Inc.                  NaN
# 4                NaN  Equifruit, Inc.                  NaN
# 5                NaN  Equifruit, Inc.                  NaN
# 6                NaN  Equifruit, Inc.                  NaN
# 7                NaN  Equifruit, Inc.                  NaN
# 8                NaN  Equifruit, Inc.                  NaN
# 9                NaN  Equifruit, Inc.                  NaN
#
# [10 rows x 75 columns]

# %%
df_purchase.shape
# Out:
# (977, 75)

# %%
df_purchase.columns
# Out:
# Index(['Status', 'Number', 'Seller', 'Carrier', 'Amount', 'Quantity',
#        'Invoiced', 'Departure Date', 'Arrival Date', 'Port of Arrival',
#        'PARS number', 'Shipping Date', 'ISF', 'Amount (CAD)',
#        'Unbilled Balance (CAD)', 'Unpaid Balance (CAD)', 'Temperature',
#        'Job:Description', 'Job:Expense', 'Job:Income', 'Job:Customer', 'Type',
#        'Attachments', 'Partially Received', 'Received Quantity', 'Reference',
#        'Date', 'Employee', 'Buyer', 'Job', 'Weight (lb)', 'Volume (ft³)',
#        'Approved By', 'Approved Date', 'Payment Terms', 'Incoterms', 'Notes',
#        'Currency', 'Billing Address', 'Shipping Address', 'Seller Address',
#        'Modes of Transportation', 'Last Event', 'Online', 'Exchange Rate',
#        'Is Cancelled', 'Reverse Exchange Rate', 'Paid', 'Division',
#        'Template Name', 'Tax Amt. (CAD)', 'Amt. Before Tax (CAD)',
#        'Other Charges (CAD)', 'Items Amount (CAD)', 'Online Creator',
#        'Is Printed', 'Pallets', 'Ventilation', 'Container#', 'Bill of Lading',
#        'US Customs', 'Canadian Customs', 'Customer', 'Remark', 'Examination',
#        'Job:Due Date', 'Temperature Recorder', 'Band Packaging',
#        'Sticker Packaging', 'Cases Packaging', 'Cornerboards Packaging',
#        'Port of Loading', 'Customs Clearance', 'Buyer:Name',
#        'Buyer:Account Number'],
#       dtype='object')

# %%
dfp=pd.read_csv('Cleaned_data/Purchase_fact.csv', encoding='cp1252')
dfp.head()
# Out:
#   Status  Number                                      Seller        Carrier  \
# 0   Open    4637  Marplantis Organic Sustainable Agriculture         Maersk
# 1   Open    4634            C.I. AGRICOLAS LAS FLORES S.A.S.  Dole Shipping
# 2   Open    4631                                 Latbio S.A.         Maersk
# 3   Open    4630                  Hacienda Celia MarÃ­a C.A.         Maersk
# 4   Open    4633            C.I. AGRICOLAS LAS FLORES S.A.S.       Seaboard
#
#          Amount  Quantity Invoiced Departure Date Arrival Date  \
# 0  USD 12690.00       900       No        1/18/25       2/3/25
# 1  USD 13536.00       960       No        1/25/25       2/2/25
# 2      USD 0.00       900       No        1/18/25       2/3/25
# 3  USD 12807.00       900       No        1/18/25       2/3/25
# 4  USD 13536.00       960       No        1/25/25       2/4/25
#
#   Port of Arrival  ... Items Amount (CAD)              Pallets Ventilation  \
# 0    Philadelphia  ...          18,337.05  Walk Global/Escobar        25.0
# 1      Wilmington  ...          19,545.98                 Chep        25.0
# 2    Philadelphia  ...                  0  Walk Global/Escobar        25.0
# 3    Philadelphia  ...          18,493.31  Walk Global/Escobar        25.0
# 4    Philadelphia  ...          19,545.98                 Chep        25.0
#
#   Container# Bill of Lading  Canadian Customs Job:Due Date  \
# 0        NaN  MAEU249009979            <none>      1/10/25
# 1        NaN            NaN            <none>       1/8/25
# 2        NaN  MAEU248914945            <none>       1/8/25
# 3        NaN  MAEU248914871            <none>       1/8/25
# 4        NaN            NaN            <none>       1/8/25
#
#   Cornerboards Packaging  Port of Loading Customs Clearance
# 0               Plastico   Puerto Bolivar               NaN
# 1                 Carton      Santa Marta               NaN
# 2               Plastico   Puerto Bolivar               NaN
# 3               Plastico   Puerto Bolivar               NaN
# 4                 Carton      Santa Marta               NaN
#
# [5 rows x 42 columns]

# %%
dfp.nunique()
# Out:
# Status                      6
# Number                    977
# Seller                     11
# Carrier                    13
# Amount                    169
# Quantity                   12
# Invoiced                    2
# Departure Date            222
# Arrival Date              208
# Port of Arrival             7
# Shipping Date             296
# ISF                         3
# Amount (CAD)              525
# Unbilled Balance (CAD)     33
# Unpaid Balance (CAD)       25
# Temperature                 2
# Job:Expense               907
# Job:Income                485
# Received Quantity          11
# Date                      114
# Employee                    2
# Job                       972
# Weight (lb)                12
# Volume (ftÂ³)              12
# Approved Date               2
# Payment Terms               3
# Incoterms                   2
# Seller Address             11
# Exchange Rate               7
# Reverse Exchange Rate      12
# Paid                        2
# Amt. Before Tax (CAD)     525
# Items Amount (CAD)        537
# Pallets                     4
# Ventilation                 1
# Container#                802
# Bill of Lading            820
# Canadian Customs            2
# Job:Due Date              227
# Cornerboards Packaging      3
# Port of Loading             9
# Customs Clearance           2
# dtype: int64

# %%
summary = []

for col in dfp.columns:
    unique_vals = dfp[col].unique()
    value_counts = dfp[col].value_counts().to_dict()
    summary.append({
        "column": col,
        "n_unique": len(unique_vals),
        "unique_values": unique_vals,
        "value_counts": value_counts
    })

df_summary = pd.DataFrame(summary)
df_summary
# Out:
#                     column  n_unique  \
# 0                   Status         6
# 1                   Number       977
# 2                   Seller        11
# 3                  Carrier        14
# 4                   Amount       169
# 5                 Quantity        12
# 6                 Invoiced         2
# 7           Departure Date       223
# 8             Arrival Date       209
# 9          Port of Arrival         8
# 10           Shipping Date       297
# 11                     ISF         3
# 12            Amount (CAD)       525
# 13  Unbilled Balance (CAD)        33
# 14    Unpaid Balance (CAD)        25
# 15             Temperature         2
# 16             Job:Expense       907
# 17              Job:Income       486
# 18       Received Quantity        12
# 19                    Date       115
# 20                Employee         3
# 21                     Job       973
# 22             Weight (lb)        13
# 23           Volume (ftÂ³)        13
# 24           Approved Date         3
# 25           Payment Terms         4
# 26               Incoterms         3
# 27          Seller Address        12
# 28           Exchange Rate         8
# 29   Reverse Exchange Rate        13
# 30                    Paid         3
# 31   Amt. Before Tax (CAD)       526
# 32      Items Amount (CAD)       538
# 33                 Pallets         5
# 34             Ventilation         2
# 35              Container#       803
# 36          Bill of Lading       821
# 37        Canadian Customs         3
# 38            Job:Due Date       228
# 39  Cornerboards Packaging         4
# 40         Port of Loading        10
# 41       Customs Clearance         3
#
#                                         unique_values  \
# 0   [Open, On Hand, Loading, Delivered, Empty, In ...
# 1   [4637, 4634, 4631, 4630, 4633, 4632, 4626, 462...
# 2   [Marplantis Organic Sustainable Agriculture, C...
# 3   [Maersk, Dole Shipping, Seaboard, COSCO Shippi...
# 4   [USD 12690.00, USD 13536.00, USD 0.00, USD 128...
# 5   [900, 960, 720, 798, 768, 906, 0, 903, 930, 96...
# 6                                           [No, Yes]
# 7   [1/18/25, 1/25/25, 1/17/25, 1/19/25, 1/11/25, ...
# 8   [2/3/25, 2/2/25, 2/4/25, 1/29/25, 1/26/25, 1/3...
# 9   [Philadelphia, Wilmington, San Diego, nan, Hal...
# 10  [2/13/25, 2/10/25, 2/12/25, 2/11/25, 2/6/25, 2...
# 11                                  [<none>, Yes, No]
# 12  [18,337.05, 19,545.98, 0, 18,493.31, 19,268.74...
# 13  [18,337.05, 19,545.98, 0, 18,493.31, 19,268.74...
# 14  [0, 9,470.96, 9,262.67, 9,178.05, 26,329.90, 9...
# 15                                       [13.9, 13.5]
# 16  [18,337.05, 19,545.98, 0, 18,493.31, 19,268.74...
# 17  [0, 33,006.37, 32,632.96, 34,850.52, 33,768.81...
# 18  [0.0, 960.0, 900.0, 768.0, 720.0, 906.0, 903.0...
# 19  [1/10/25, 1/8/25, 1/7/25, 12/31/24, 12/30/24, ...
# 20                  [David Melo, Naomi Bendayan, nan]
# 21  [4637.0, 4634.0, 4631.0, 4630.0, 4633.0, 4632....
# 22  [35,992.67, 38,392.18, 0, 35,991.00, 38,390.40...
# 23  [1,906.99, 2,034.12, 1,908.00, 0, 1,525.59, 1,...
# 24                           [nan, 1/24/25, 11/11/24]
# 25              [nan, Net 10, Due on receipt, Net 30]
# 26                                    [FOB, nan, EXW]
# 27  [DATILES 416 Y CALLE 6TA, GUAYAQUIL, GUAYAS Ec...
# 28     [0.69, 0.7, 0.71, 0.72, 0.73, 0.74, 0.33, nan]
# 29  [1.45, 1.44, 1.43, 1.42, 1.41, 1.4, 1.39, 1.38...
# 30                                     [No, Yes, nan]
# 31  [18,337.05, 19,545.98, 0, 18,493.31, 19,268.74...
# 32  [18,337.05, 19,545.98, 0, 18,493.31, 19,268.74...
# 33  [Walk Global/Escobar, Chep, Tipo CHEP, Standar...
# 34                                        [25.0, nan]
# 35  [nan, SMLU5465414, CAAU4104110, TEXU9523830, S...
# 36  [MAEU249009979, nan, MAEU248914945, MAEU248914...
# 37                                 [<none>, Yes, nan]
# 38  [1/10/25, 1/8/25, 1/7/25, 12/31/24, 12/30/24, ...
# 39        [Plastico, Carton, Plastico reciclado, nan]
# 40  [Puerto Bolivar, Santa Marta, Guayaquil, Nogal...
# 41                 [nan, Canada Inbond, US Clearance]
#
#                                          value_counts
# 0   {'Delivered': 838, 'On Hand': 57, 'Open': 45, ...
# 1   {4637: 1, 3534: 1, 3539: 1, 3542: 1, 3538: 1, ...
# 2   {'ASOGUABO': 292, 'Marplantis Organic Sustaina...
# 3   {'Maersk': 451, 'Seaboard': 146, 'ONE': 90, 'Z...
# 4   {'USD 12690.00': 208, 'USD 13095.00': 81, 'USD...
# 5   {900: 584, 960: 343, 720: 29, 930: 8, 0: 4, 90...
# 6                              {'Yes': 905, 'No': 72}
# 7   {'11/30/24': 20, '4/20/24': 19, '12/7/24': 19,...
# 8   {'9/30/24': 21, '1/6/25': 21, '6/3/24': 17, '1...
# 9   {'Philadelphia': 769, 'Hueneme': 47, 'Wilmingt...
# 10  {'12/2/24': 9, '12/16/24': 9, '12/25/24': 8, '...
# 11              {'Yes': 828, 'No': 101, '<none>': 48}
# 12  {'17,359.92': 13, '17,461.44': 12, '17,512.20'...
# 13  {'0': 910, '23,043.94': 6, '23,107.84': 6, '18...
# 14  {'0': 942, '9,178.05': 8, '9,105.07': 4, '9,44...
# 15                             {13.9: 580, 13.5: 397}
# 16  {'23,043.94': 6, '23,107.84': 6, '18,290.99': ...
# 17  {'0': 104, '32,983.85': 22, '34,850.52': 20, '...
# 18  {900.0: 551, 960.0: 333, 0.0: 49, 720.0: 27, 9...
# 19  {'8/13/24': 22, '9/18/24': 21, '7/24/24': 20, ...
# 20           {'David Melo': 973, 'Naomi Bendayan': 3}
# 21  {3772.0: 2, 3767.0: 2, 3976.0: 2, 3780.0: 2, 3...
# 22  {'35,992.67': 505, '38,392.18': 310, '0': 57, ...
# 23  {'1,906.99': 505, '2,034.12': 300, '1,908.00':...
# 24                      {'1/24/25': 1, '11/11/24': 1}
# 25  {'Due on receipt': 337, 'Net 10': 57, 'Net 30'...
# 26                            {'FOB': 928, 'EXW': 29}
# 27  {'VIA PANAMERICANA SUR Y QUINTA OESTE, El Guab...
# 28  {0.73: 465, 0.72: 192, 0.74: 118, 0.71: 102, 0...
# 29  {1.37: 244, 1.38: 240, 1.36: 141, 1.41: 68, 1....
# 30                            {'Yes': 869, 'No': 107}
# 31  {'17,359.92': 13, '17,461.44': 12, '22,468.35'...
# 32  {'17,359.92': 13, '17,461.44': 12, '17,512.20'...
# 33  {'Walk Global/Escobar': 501, 'Chep': 237, 'Tip...
# 34                                        {25.0: 976}
# 35  {'CAIU5553320': 2, 'SMLU5461091': 2, 'MNBU3786...
# 36  {'MAEU244531240': 2, 'SMLU8227048A': 2, 'MAEU2...
# 37                          {'<none>': 975, 'Yes': 1}
# 38  {'11/28/24': 21, '11/22/24': 21, '11/6/24': 21...
# 39  {'Plastico': 528, 'Plastico reciclado': 365, '...
# 40  {'Puerto Bolivar': 381, 'Guayaquil': 300, 'Pha...
# 41         {'US Clearance': 374, 'Canada Inbond': 79}

# %%
df_original = pd.read_csv('Raw data_magaya/Sales Orders/Sales Order Lines.csv', encoding='cp1252')
df_original
# Out:
#         Status Sales Order  Line No.  \
# 0       Loaded        4536         1
# 1       Loaded        4533         1
# 2       Loaded        4565         1
# 3       Loaded        4543         1
# 4       Loaded        4537         1
# ..         ...         ...       ...
# 149  Delivered        3976         1
# 150  Delivered        3931         1
# 151  Delivered        3956         1
# 152  Delivered        3968         1
# 153  Delivered        3992         1
#
#                                            Description Part Number  Quantity  \
# 0    Banano Cavendish Organico Fairtrade 3lb con Ba...    007ECMAR       900
# 1    Banano Cavendish Organico Fairtrade 3lb con Ba...    007ECSUR       900
# 2    Banano Cavendish Organico Fairtrade 3lb con Ba...    007MXCOL       855
# 3    Banano Cavendish Organico Fairtrade 3lb con Ba...    007MXCOL       900
# 4    Banano Cavendish Organico Fairtrade 3lb con Ba...    007ECSUR       900
# ..                                                 ...         ...       ...
# 149      Banano Cavendish Organico Fairtrade con banda    001MXCOL       720
# 150  Banano Cavendish Convencional Fairtrade con et...    004NICOQ       960
# 151      Banano Cavendish Organico Fairtrade con banda    001COCIA       960
# 152  Banano Cavendish Organico Fairtrade 3lb con Ba...    007ECSUR       900
# 153  Banano Cavendish Organico Fairtrade 3lb con Ba...    007ECMAR       900
#
#      Price     Amount  Promised Date   Unit  Tax Code  Tax Rate  Tax Amt.  \
# 0     0.00       0.00            NaN  Cases       NaN       0.0       0.0
# 1    26.77  24,093.00            NaN    NaN       NaN       0.0       0.0
# 2    26.77  22,888.35            NaN  Cases       NaN       0.0       0.0
# 3    26.77  24,093.00            NaN  Cases       NaN       0.0       0.0
# 4    26.77  24,093.00            NaN    NaN       NaN       0.0       0.0
# ..     ...        ...            ...    ...       ...       ...       ...
# 149  28.02  20,174.40            NaN  Cases       NaN       0.0       0.0
# 150  22.21  21,321.60            NaN  Cases       NaN       0.0       0.0
# 151  24.36  23,385.60            NaN  Cases       NaN       0.0       0.0
# 152  25.11  22,599.00            NaN    NaN       NaN       0.0       0.0
# 153  26.77  24,093.00            NaN  Cases       NaN       0.0       0.0
#
#       Amt.+Tax Is Cancelled
# 0         0.00           No
# 1    24,093.00           No
# 2    22,888.35           No
# 3    24,093.00           No
# 4    24,093.00           No
# ..         ...          ...
# 149  20,174.40           No
# 150  21,321.60           No
# 151  23,385.60           No
# 152  22,599.00           No
# 153  24,093.00           No
#
# [154 rows x 15 columns]

# %%
import pandas as pd
df_job = pd.read_csv('/Users/chloe/Desktop/Banana_project/Cleaned_data/Commodity_list.csv', encoding='cp1252')
df_job
# Out:
#       Status  Job:Number Incoming Shipment:Name  \
# 0    Ordered      4637.0                    NaN
# 1    Ordered      4634.0                    NaN
# 2    Ordered      4631.0                    NaN
# 3    Ordered      4630.0                    NaN
# 4    Ordered      4633.0                    NaN
# ..       ...         ...                    ...
# 139  On Hand      2106.0                   2106
# 140  On Hand      2081.0                   2081
# 141  On Hand      1953.0                   1953
# 142  On Hand      1953.0                   1953
# 143  On Hand      1953.0                   1953
#
#                           Purchase Order:Seller Purchase Order:Carrier  \
# 0    Marplantis Organic Sustainable Agriculture                 Maersk
# 1              C.I. AGRICOLAS LAS FLORES S.A.S.          Dole Shipping
# 2                                   Latbio S.A.                 Maersk
# 3                    Hacienda Celia MarÃ­a C.A.                 Maersk
# 4              C.I. AGRICOLAS LAS FLORES S.A.S.               Seaboard
# ..                                          ...                    ...
# 139                                    ASOGUABO                Sealand
# 140                                     APPBOSA                Sealand
# 141                 Coliman Pacific Corporation                    NaN
# 142                 Coliman Pacific Corporation                    NaN
# 143                 Coliman Pacific Corporation                    NaN
#
#     Purchase Order:Container# Purchase Order:Bill of Lading  \
# 0                         NaN                 MAEU249009979
# 1                         NaN                           NaN
# 2                         NaN                 MAEU248914945
# 3                         NaN                 MAEU248914871
# 4                         NaN                           NaN
# ..                        ...                           ...
# 139               MMAU1119679                     914149815
# 140               MNBU4212320                     914087027
# 141                       NaN                           NaN
# 142                       NaN                           NaN
# 143                       NaN                           NaN
#
#     Purchase Order:Harvest date Purchase Order:Departure Date  \
# 0                           NaN                    18/01/2025
# 1                           NaN                    25/01/2025
# 2                           NaN                    18/01/2025
# 3                           NaN                    18/01/2025
# 4                           NaN                    25/01/2025
# ..                          ...                           ...
# 139                         NaN                    11/04/2022
# 140                         NaN                    26/03/2022
# 141                         NaN                    27/01/2022
# 142                         NaN                    27/01/2022
# 143                         NaN                    27/01/2022
#
#     Purchase Order:Arrival Date  ... Release Order Container Number  \
# 0                    03/02/2025  ...             0              NaN
# 1                    02/02/2025  ...             0              NaN
# 2                    03/02/2025  ...             0              NaN
# 3                    03/02/2025  ...             0              NaN
# 4                    04/02/2025  ...             0              NaN
# ..                          ...  ...           ...              ...
# 139                  25/04/2022  ...             6              NaN
# 140                  11/04/2022  ...             1      MNBU4212320
# 141                  31/01/2022  ...             1              NaN
# 142                  31/01/2022  ...             2              NaN
# 143                  31/01/2022  ...             5              NaN
#
#      Contained Item                                Manufacturer PO Line  \
# 0                No  Marplantis Organic Sustainable Agriculture       1
# 1                No            C.I. AGRICOLAS LAS FLORES S.A.S.       1
# 2                No                                 Latbio S.A.       1
# 3                No                  Hacienda Celia MarÃ­a C.A.       1
# 4                No            C.I. AGRICOLAS LAS FLORES S.A.S.       2
# ..              ...                                         ...     ...
# 139              No                                    ASOGUABO       2
# 140             Yes                                     APPBOSA       1
# 141              No                 Coliman Pacific Corporation       2
# 142              No                 Coliman Pacific Corporation       1
# 143              No                 Coliman Pacific Corporation       1
#
#     SO Line  Lead Time Imported Warehouse Receipt Number  \
# 0         0          0                               NaN
# 1         0          0                               NaN
# 2         0          0                               NaN
# 3         0          0                               NaN
# 4         0          0                               NaN
# ..      ...        ...                               ...
# 139       2         28                              2106
# 140       1         28                              2081
# 141       2         29                              1953
# 142       1         29                              1953
# 143       1         29                              1953
#
#     Imported Pickup Order Number Incoming Shipment:Notify Party
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                            NaN                                 NaN
# ..                           ...                                 ...
# 139                          NaN           Chiovitti Banana Co., Ltd
# 140                          NaN                   Courchesne Larose
# 141                          NaN           Chiovitti Banana Co., Ltd
# 142                          NaN           Chiovitti Banana Co., Ltd
# 143                          NaN           Chiovitti Banana Co., Ltd
#
# [144 rows x 88 columns]

# %%
df_job.columns
# Out:
# Index(['Status', 'Job:Number', 'Incoming Shipment:Name',
#        'Purchase Order:Seller', 'Purchase Order:Carrier',
#        'Purchase Order:Container#', 'Purchase Order:Bill of Lading',
#        'Purchase Order:Harvest date', 'Purchase Order:Departure Date',
#        'Purchase Order:Arrival Date', 'Part Number',
#        'Item Definition:Categories', 'Pieces', 'Purchase Order:Customer',
#        'Sales Order:Buyer', 'Purchase Order:Shipping Date',
#        'Cargo Release:Purchase Order', 'Purchase Order:Port of Arrival',
#        'Purchase Order:ISF', 'Purchase Order:US Customs',
#        'Purchase Order:Canadian Customs', 'Purchase Order:PARS number',
#        'Purchase Order:Temperature', 'Purchase Order:Ventilation',
#        'Purchase Order:Pallets', 'Purchase Order:Number',
#        'Incoming Shipment:Container Number',
#        'Incoming Shipment:Master Waybill', 'Sales Order:Billing Client',
#        'Warehouse Receipt Date', 'Departure Date', 'Arrival Date',
#        'Description', 'Incoming Shipment:Waybill Number', 'Package',
#        'Length (in)', 'Height (in)', 'Width (in)', 'Weight (lb)',
#        'Volume (ftÂ³)', 'Pickup Order:Number', 'Location Code',
#        'Location Description', 'Piece Weight (lb)', 'Piece Volume (ftÂ³)',
#        'Model', 'Purchase Order Number', 'Warehouse Receipt', 'Pickup Order',
#        'Cargo Release', 'Waybill (in)', 'Master Waybill (in)', 'Shipper',
#        'Consignee', 'WHR Shipper', 'WHR Consignee', 'Issued By',
#        'Carrier (in)', 'Notify Party     ', 'Place of Delivery', 'Entry Date',
#        'Quantity', 'Unitary Value', 'Value', 'Unit', 'Item ID',
#        'Modes of Transportation', 'Origin Port', 'Destination Port',
#        'Secondary Description', 'Dimensions', 'Arrival Date (Incoming)',
#        'Volume weight (Vlb)', 'Chargeable Weight (lb)', 'Job Number',
#        'Sales Order Number', 'In Pallet', 'Previous Location', 'Release Order',
#        'Container Number', 'Contained Item', 'Manufacturer', 'PO Line',
#        'SO Line', 'Lead Time', 'Imported Warehouse Receipt Number',
#        'Imported Pickup Order Number', 'Incoming Shipment:Notify Party     '],
#       dtype='object')

# %%
df_job.rename(columns={"Job:Number":'Job'}, inplace=True)

# %%
df_job['job'] = df_job['job'].astype(int)
df_job.to_csv("Commodity_list.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df_job['job'] = df_job['job'].astype(int)
#       2 df_job.to_csv("Commodity_list.csv", index=False)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
summary = []

for col in df_job.columns:
    unique_vals = df_job[col].unique()
    value_counts = df_job[col].value_counts().to_dict()
    summary.append({
        "column": col,
        "n_unique": len(unique_vals),
        "unique_values": unique_vals,
        "value_counts": value_counts
    })

df_summary = pd.DataFrame(summary)
df_summary
# Out:
#                                  column  n_unique  \
# 0                                Status         4
# 1                                   job       132
# 2                Incoming Shipment:Name        86
# 3                 Purchase Order:Seller        11
# 4                Purchase Order:Carrier        13
# ..                                  ...       ...
# 83                              SO Line         4
# 84                            Lead Time        20
# 85    Imported Warehouse Receipt Number        86
# 86         Imported Pickup Order Number         2
# 87  Incoming Shipment:Notify Party             13
#
#                                         unique_values  \
# 0            [Ordered, On Hand, In Transit, Arriving]
# 1   [4637.0, 4634.0, 4631.0, 4630.0, 4633.0, 4632....
# 2   [nan, 4619, 4618, 4617, 4616, 4615, 4608, 4607...
# 3   [Marplantis Organic Sustainable Agriculture, C...
# 4   [Maersk, Dole Shipping, Seaboard, COSCO Shippi...
# ..                                                ...
# 83                                       [0, 1, 3, 2]
# 84  [0, 1, 7, 8, 11, 5, 10, 25, 24, 19, 13, 9, 34,...
# 85  [nan, 4619, 4618, 4617, 4616, 4615, 4608, 4607...
# 86                                      [nan, 2967.0]
# 87  [nan, Courchesne Larose, Chiovitti Banana Co.,...
#
#                                          value_counts
# 0   {'On Hand': 94, 'Ordered': 47, 'In Transit': 2...
# 1   {1953.0: 3, 2106.0: 3, 2208.0: 3, 4520.0: 2, 2...
# 2   {'1953': 3, '2106': 3, '2208': 3, '2131': 2, '...
# 3   {'ASOGUABO': 47, 'Coliman Pacific Corporation'...
# 4   {'Maersk': 45, 'Sealand': 21, 'ZIM': 13, 'Dole...
# ..                                                ...
# 83                        {0: 109, 1: 26, 2: 6, 3: 3}
# 84  {0: 55, 5: 25, 28: 16, 7: 11, 8: 9, 11: 5, 9: ...
# 85  {'1953': 3, '2106': 3, '2208': 3, '2131': 2, '...
# 86                                        {2967.0: 1}
# 87  {'Chiovitti Banana Co., Ltd': 45, 'Courchesne ...
#
# [88 rows x 4 columns]

# %%
import pandas as pd

df = pd.read_csv("Cleaned_data/Cargo_Releases_List.csv")
df.head(20)
# Out:
#     Status   Number Release Date  \
# 0   Loaded     4543   01/13/2025
# 1   Loaded     4565   01/13/2025
# 2   Loaded     4536   01/13/2025
# 3   Loaded     4550   01/13/2025
# 4   Loaded     4533   01/13/2025
# 5   Loaded     4532   01/12/2025
# 6   Loaded     4560   01/12/2025
# 7   Loaded     4537   01/12/2025
# 8   Loaded     4562   01/10/2025
# 9   Loaded   4527CH   01/10/2025
# 10  Loaded     4531   01/10/2025
# 11  Loaded  4575BCH   01/10/2025
# 12  Loaded     4575   01/10/2025
# 13  Loaded     4572   01/10/2025
# 14  Loaded     4564   01/10/2025
# 15  Loaded     4528   01/09/2025
# 16  Loaded     4526   01/09/2025
# 17  Loaded     4500   01/08/2025
# 18  Loaded    4527S   01/08/2025
# 19  Loaded     4545   01/08/2025
#
#                                       Released to  Pieces Weight (lb)  \
# 0               Krown Produce  Fresh At Its Best™       1    3,747.86
# 1                       Chiovitti Banana Co., Ltd     855   34,193.04
# 2                       Chiovitti Banana Co., Ltd       1    3,747.86
# 3                               Courchesne Larose       1    3,747.86
# 4                               Courchesne Larose       1    3,747.86
# 5                       Chiovitti Banana Co., Ltd       1    3,747.86
# 6                       Chiovitti Banana Co., Ltd       1    3,747.86
# 7                               Courchesne Larose       1    3,747.86
# 8                       Chiovitti Banana Co., Ltd       1    3,747.86
# 9                                Charlies Seattle     720   28,794.14
# 10                      Chiovitti Banana Co., Ltd       1    3,747.86
# 11                                     Sobeys BCH     720   28,794.14
# 12                             Sobeys Quebec City     240    9,598.05
# 13              Krown Produce  Fresh At Its Best™       1    3,747.86
# 14                      Chiovitti Banana Co., Ltd       1    3,747.86
# 15                      Chiovitti Banana Co., Ltd       1    3,747.86
# 16                      Chiovitti Banana Co., Ltd       1    3,747.86
# 17                      Chiovitti Banana Co., Ltd       1    3,747.86
# 18  Sprouts Farmers Market - Distribution Centers      48        0.00
# 19                              Courchesne Larose       1    3,747.86
#
#    Volume (ft³) Creation Date Income (CAD) Expense (CAD)  ...  \
# 0      2,359.59    01/11/2025    34,814.39          0.00  ...
# 1      1,811.64    01/11/2025    33,073.67          0.00  ...
# 2      2,359.59    01/11/2025         0.00          0.00  ...
# 3      2,359.59    01/09/2025    35,584.78          0.00  ...
# 4      2,359.59    01/11/2025    34,814.39          0.00  ...
# 5      2,359.59    01/11/2025    34,814.39          0.00  ...
# 6      2,359.59    01/09/2025    33,768.81          0.00  ...
# 7      2,359.59    01/11/2025    34,814.39          0.00  ...
# 8      2,359.59    01/07/2025    34,573.45          0.00  ...
# 9      1,525.59    01/08/2025    28,950.26          0.00  ...
# 10     2,359.59    01/03/2025    33,827.27          0.00  ...
# 11     1,525.59    01/09/2025    24,754.78          0.00  ...
# 12       508.53    01/09/2025     8,251.59          0.00  ...
# 13     2,359.59    01/09/2025    32,632.96          0.00  ...
# 14     2,359.59    01/09/2025    34,790.29          0.00  ...
# 15     2,359.59    01/07/2025    34,573.45          0.00  ...
# 16     2,359.59    01/07/2025    34,573.45          0.00  ...
# 17     2,359.59    01/07/2025    33,558.34          0.00  ...
# 18         0.00    01/08/2025         0.00          0.00  ...
# 19     2,359.59    01/07/2025    34,573.45          0.00  ...
#
#                               Commodities Description  \
# 0                                                 NaN
# 1   Banano Cavendish Organico Fairtrade 3lb con Ba...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9       Banano Cavendish Organico Fairtrade con banda
# 10                                                NaN
# 11      Banano Cavendish Organico Fairtrade con banda
# 12      Banano Cavendish Organico Fairtrade con banda
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Banano Cavendish Organico Fairtrade con Banda ...
# 19                                                NaN
#
#                                     Issued By Address  \
# 0   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 1   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 2   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 3   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 4   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 5   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 6   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 7   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 8   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 9   5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 10  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 11  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 12  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 13  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 14  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 15  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 16  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 17  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 18  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
# 19  5311, boulevard de Maisonneuve ouest\r\r\nSuit...
#
#                                    Release to Address Purchase Order Number  \
# 0   4923 47th Street SE,, Calgary, AB T2B 3S5. Canada                   NaN
# 1    26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 2    26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 3   9761 boul. des Sciences, Montréal, QC H1J 0A6....                   NaN
# 4   9761 boul. des Sciences, Montréal, QC H1J 0A6....                   NaN
# 5    26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 6    26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 7   9761 boul. des Sciences, Montréal, QC H1J 0A6....                   NaN
# 8    26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 9   5033 1st Ave S, Seattle 98134, Seattle, WA 981...                   NaN
# 10   26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 11  1500 Bd de Montarville, Boucherville, QC J4B 5...                   NaN
# 12  950, avenue Galilee, Duberger, QC G1P 4B7. Canada                   NaN
# 13  4923 47th Street SE,, Calgary, AB T2B 3S5. Canada                   NaN
# 14   26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 15   26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 16   26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 17   26 Magnificent Road, Toronto, ON M8Z 4T3. Canada                   NaN
# 18  5445 West Missouri Ave, Glendale, AZ 85301. Un...                   NaN
# 19  9761 boul. des Sciences, Montréal, QC H1J 0A6....                   NaN
#
#                                    Billing Client Is Printed Purchase Order  \
# 0               Krown Produce  Fresh At Its Best™         No         AL1739
# 1                       Chiovitti Banana Co., Ltd         No         250354
# 2                       Chiovitti Banana Co., Ltd         No         250241
# 3                               Courchesne Larose        Yes        2486593
# 4                               Courchesne Larose         No     5741231077
# 5                       Chiovitti Banana Co., Ltd         No         250353
# 6                       Chiovitti Banana Co., Ltd        Yes         250355
# 7                               Courchesne Larose         No     5741231066
# 8                       Chiovitti Banana Co., Ltd         No         250240
# 9                                Charlies Seattle         No        7002396
# 10                      Chiovitti Banana Co., Ltd         No         250234
# 11                                     Sobeys BCH         No     4567010098
# 12                             Sobeys Quebec City         No     4567010205
# 13              Krown Produce  Fresh At Its Best™         No         AL1704
# 14                      Chiovitti Banana Co., Ltd         No         250239
# 15                      Chiovitti Banana Co., Ltd         No         250238
# 16                      Chiovitti Banana Co., Ltd         No         250235
# 17                      Chiovitti Banana Co., Ltd         No         250234
# 18  Sprouts Farmers Market - Distribution Centers         No     0980162917
# 19                              Courchesne Larose         No     5741231060
#
#    Delivery date Lot Number   Container#
# 0            NaN        NaN          NaN
# 1            NaN        NaN          NaN
# 2            NaN        NaN          NaN
# 3            NaN        NaN  SEGU9465097
# 4            NaN        NaN          NaN
# 5            NaN        NaN          NaN
# 6            NaN        NaN  BMOU9887238
# 7            NaN        NaN          NaN
# 8            NaN        NaN          NaN
# 9            NaN        NaN          NaN
# 10           NaN        NaN  TEMU9696277
# 11           NaN        NaN  BEAU9710377
# 12           NaN        NaN  BEAU9710377
# 13           NaN        NaN  CAAU4105992
# 14           NaN        NaN          NaN
# 15           NaN        NaN          NaN
# 16           NaN        NaN          NaN
# 17           NaN        NaN          NaN
# 18           NaN        NaN          NaN
# 19           NaN        NaN          NaN
#
# [20 rows x 26 columns]

# %%
summary = []

for col in df.columns:
    unique_vals = df[col].unique()
    value_counts = df[col].value_counts().to_dict()
    summary.append({
        "column": col,
        "n_unique": len(unique_vals),
        "unique_values": unique_vals,
        "value_counts": value_counts
    })

df_summary = pd.DataFrame(summary)
df_summary
# Out:
#                      column  n_unique  \
# 0                    Status         4
# 1                    Number      3050
# 2              Release Date       997
# 3               Released to        24
# 4                    Pieces        47
# 5               Weight (lb)        56
# 6              Volume (ft³)        51
# 7             Creation Date       659
# 8              Income (CAD)      1944
# 9             Expense (CAD)         7
# 10            Balance (CAD)      1946
# 11    Exclude From Tracking         2
# 12      Volume weight (Vlb)        52
# 13                 Employee         9
# 14                    Notes        34
# 15                  Carrier        55
# 16  Commodities Description        30
# 17        Issued By Address         2
# 18       Release to Address        25
# 19    Purchase Order Number         6
# 20           Billing Client        20
# 21               Is Printed         2
# 22           Purchase Order      2917
# 23            Delivery date        31
# 24               Lot Number        63
# 25               Container#       504
#
#                                         unique_values  \
# 0              [Loaded, Delivered, In Transit, Empty]
# 1   [4543, 4565, 4536, 4550, 4533, 4532, 4560, 453...
# 2   [01/13/2025, 01/12/2025, 01/10/2025, 01/09/202...
# 3   [Krown Produce  Fresh At Its Best™, Chiovitti ...
# 4   [1, 855, 720, 240, 48, 672, 288, 900, 960, 810...
# 5   [3,747.86, 34,193.04, 28,794.14, 9,598.05, 0.0...
# 6   [2,359.59, 1,811.64, 1,525.59, 508.53, 0.00, 1...
# 7   [01/11/2025, 01/09/2025, 01/07/2025, 01/08/202...
# 8   [34,814.39, 33,073.67, 0.00, 35,584.78, 33,768...
# 9   [0.00, 13,960.80, 4,653.60, 1,012.53, 14,829.3...
# 10  [34,814.39, 33,073.67, 0.00, 35,584.78, 33,768...
# 11                                          [No, Yes]
# 12  [24,562.48, 18,858.54, 15,880.88, 5,293.63, 0....
# 13  [Claudia Ramirez, Naomi Bendayan, Marie Lamare...
# 14  [nan, Country of Origin: Mexico, Country of Or...
# 15  [CTX, TQL, Holt, nan, Savoie, Connors, JE FORT...
# 16  [nan, Banano Cavendish Organico Fairtrade 3lb ...
# 17  [5311, boulevard de Maisonneuve ouest\r\r\nSui...
# 18  [4923 47th Street SE,, Calgary, AB T2B 3S5. Ca...
# 19  [nan, 2199, Please set temp to 64 def F contin...
# 20  [Krown Produce  Fresh At Its Best™, Chiovitti ...
# 21                                          [No, Yes]
# 22  [AL1739, 250354, 250241, 2486593, 5741231077, ...
# 23  [nan, 01/04/2025, 07/31/2024, 06/08/2024, 05/1...
# 24  [nan, 0011E721, 0011e815, 0011E452, 0011E919, ...
# 25  [nan, SEGU9465097, BMOU9887238, TEMU9696277, B...
#
#                                          value_counts
# 0   {'Delivered': 2996, 'Loaded': 37, 'Empty': 22,...
# 1   {'2319': 2, '2131G': 2, '2129W': 2, '4235QC': ...
# 2   {'03/21/2023': 9, '02/09/2023': 8, '11/18/2024...
# 3   {'Chiovitti Banana Co., Ltd': 1481, 'Courchesn...
# 4   {1: 2186, 240: 117, 288: 110, 480: 110, 672: 8...
# 5   {'3,747.86': 1433, '0.00': 599, '42,140.04': 1...
# 6   {'2,359.59': 1372, '2,359.37': 449, '0.00': 28...
# 7   {'06/07/2024': 20, '09/06/2024': 19, '12/05/20...
# 8   {'0.00': 65, '31,680.00': 49, '34,780.80': 28,...
# 9   {'0.00': 3050, '13,960.80': 1, '4,653.60': 1, ...
# 10  {'0.00': 65, '31,680.00': 49, '34,780.80': 28,...
# 11                             {'No': 3055, 'Yes': 1}
# 12  {'24,562.48': 1372, '24,560.22': 449, '0.00': ...
# 13  {'Claudia Ramirez': 1750, 'Marie Lamare': 745,...
# 14  {'Country of Origin: Ecuador
#
# Please scan TIV...
# 15  {'Holt': 624, 'Savoie': 299, 'Fulger': 134, 'C...
# 16  {'Banano Cavendish Organico Fairtrade con band...
# 17  {'5311, boulevard de Maisonneuve ouest
#
# Suite...
# 18  {'26 Magnificent Road, Toronto, ON M8Z 4T3. Ca...
# 19  {'2199': 1, 'Please set temp to 64 def F conti...
# 20  {'Chiovitti Banana Co., Ltd': 1481, 'Courchesn...
# 21                             {'No': 3049, 'Yes': 7}
# 22  {'TBD': 9, '235732': 3, '574-0510200': 2, '574...
# 23  {'01/04/2025': 2, '12/01/2023': 2, '10/10/2023...
# 24  {'0011e679': 8, '0002E021': 6, '0011e464': 5, ...
# 25  {'TEMU9174919': 5, 'CGMU9321679': 5, 'SUDU9014...

# %%
from googletrans import Translator
import pandas as pd


translator = Translator()

df['item'] = df['Description'].apply(lambda x: translator.translate(x, dest='en').text)


df.shape
# Out:
# (24, 39)

# %%
summary = []

for col in df.columns:
    unique_vals = df[col].unique()
    value_counts = df[col].value_counts().to_dict()
    summary.append({
        "column": col,
        "n_unique": len(unique_vals),
        "unique_values": unique_vals,
        "value_counts": value_counts
    })

df_summary = pd.DataFrame(summary)
df_summary
# Out:
#                          column  n_unique  \
# 0                   Part Number        24
# 1                   Description         5
# 2                  Manufacturer        13
# 3                       Package         4
# 4                        Pieces        14
# 5                      Sellable         2
# 6                          Unit         3
# 7             Amount Per Pallet         3
# 8               Incoming Pieces        10
# 9                          Cost        16
# 10    Total Purchase Cost (CAD)        19
# 11          Total Billed Pieces        16
# 12                        Model         4
# 13                Creation Date        15
# 14                    Sale Item         6
# 15                Purchase Item         6
# 16             Allocated Pieces         9
# 17    Allocated Incoming Pieces         2
# 18                  Length (in)         3
# 19                   Width (in)         2
# 20                  Height (in)         2
# 21                  Weight (lb)         3
# 22                 Volume (ft³)         2
# 23     Total OnHand Weight (lb)        15
# 24             Preferred Vendor        13
# 25               Costing Method         2
# 26      Total Landed Cost (CAD)        19
# 27    Average Landed Cost (CAD)        18
# 28  Average Purchase Cost (CAD)        18
# 29            Minimum Lead Time         7
# 30            Maximum Lead Time        22
# 31              Reserved Pieces         2
# 32             Available Pieces        15
# 33                Available Now        12
# 34                   Categories         4
# 35          English Description         4
# 36           French Description         4
# 37                      english         4
# 38                         item         5
#
#                                         unique_values  \
# 0   [008PEAPP, 008MXCOL, 007PEAPP, 007MXCOL, 007EC...
# 1   [Banano Cavendish Organico Fairtrade 3lb con B...
# 2   [APPBOSA, Coliman Pacific Corporation, Surgesa...
# 3   [Bandeja Organica/Open-Top Case (Morado y verd...
# 4   [0, 1,800, 45, 2,700, 3,600, 9,900, 16,200, 1,...
# 5                                           [No, Yes]
# 6                                  [Cases, nan, Casa]
# 7                                         [48, 0, 45]
# 8   [0, 78, 16,200, 1,800, 900, 4,500, 3,600, 6,96...
# 9   [0.0, 20.4, 25.68, 21.05, 20.59, 20.33, 14.66,...
# 10  [0.00, 30,689.69, 149,237.53, 92,866.73, 35,97...
# 11  [0, 1,800, 5,400, 4,500, 10,800, 2,700, 3,600,...
# 12  [Organic banana, Organic banana , Organic Bana...
# 13  [08/01/2022, 12/31/2024, 01/12/2022, 05/04/202...
# 14  [nan, Banane Cavendish Bio & Equitable / Fairt...
# 15  [nan, Banane Cavendish Bio & Equitable / Fairt...
# 16  [0, 1,800, 900, 960, 624, 1,920, 2,880, 3,206,...
# 17                                           [0, 960]
# 18                                [16.14, 15.75, 0.0]
# 19                                       [24.02, 0.0]
# 20                                        [9.06, 0.0]
# 21                                [39.99, 0.0, 39.68]
# 22                                        [2.12, 0.0]
# 23  [0.00, 71,985.34, 1,799.63, 107,978.01, 143,96...
# 24  [nan, APPBOSA, Coliman Pacific Corporation, Su...
# 25            [Specific Identification, Average Cost]
# 26  [0.00, 30,689.69, 149,237.53, 92,866.73, 35,97...
# 27  [0.0, 17.05, 27.64, 20.64, 19.99, 20.31, 20.06...
# 28  [0.0, 17.05, 27.64, 20.64, 19.99, 20.31, 20.06...
# 29                            [0, 29, 2, 4, 1, 12, 9]
# 30  [0, 29, 34, 57, 47, 33, 218, 26, 20, 48, 182, ...
# 31                                            [0, 96]
# 32  [0, 78, 16,245, 3,600, 4,500, 13,500, 2,700, 1...
# 33  [0, 45, 1,800, 3,600, 9,000, 14,400, 960, 1,15...
# 34               [nan, Costco, Conventional, Organic]
# 35  [Organic and Fairtrade Cavendish Banana 3lb, n...
# 36  [Banane Cavendish Biologique et Fairtrade 3lb,...
# 37  [Organic Tray/Open-Top Case (purple and green)...
# 38  [Banano Cavendish Organic FairTrade 3LB with b...
#
#                                          value_counts
# 0   {'008PEAPP': 1, '008MXCOL': 1, '001CODAA': 1, ...
# 1   {'Banano Cavendish Organico Fairtrade 3lb con ...
# 2   {'Coliman Pacific Corporation': 4, 'APPBOSA': ...
# 3   {'Caja con tapa organica (morado y verde)': 11...
# 4   {'0': 8, '1,800': 2, '3,600': 2, '4,800': 2, '...
# 5                                {'Yes': 21, 'No': 3}
# 6                            {'Cases': 19, 'Casa': 1}
# 7                               {48: 14, 45: 7, 0: 3}
# 8   {'0': 13, '900': 3, '78': 1, '16,200': 1, '1,8...
# 9   {0.0: 5, 20.4: 5, 25.68: 1, 21.05: 1, 20.59: 1...
# 10  {'0.00': 6, '75,599.24': 1, '241,523.56': 1, '...
# 11  {'0': 7, '1,800': 2, '2,880': 2, '5,400': 1, '...
# 12  {'Organic banana': 18, 'Convencional banana': ...
# 13  {'12/12/2021': 8, '10/06/2022': 3, '08/01/2022...
# 14  {'Banane Cavendish Bio & Equitable / Fairtrade...
# 15  {'Banane Cavendish Bio & Equitable / Fairtrade...
# 16  {'0': 13, '1,800': 2, '900': 2, '960': 2, '624...
# 17                                    {0: 23, 960: 1}
# 18                      {15.75: 20, 0.0: 3, 16.14: 1}
# 19                                {24.02: 21, 0.0: 3}
# 20                                 {9.06: 21, 0.0: 3}
# 21                      {39.99: 19, 0.0: 4, 39.68: 1}
# 22                                 {2.12: 21, 0.0: 3}
# 23  {'0.00': 9, '71,985.34': 2, '1,799.63': 1, '10...
# 24  {'Coliman Pacific Corporation': 3, 'ASOGUABO':...
# 25  {'Specific Identification': 16, 'Average Cost'...
# 26  {'0.00': 6, '75,599.24': 1, '241,523.56': 1, '...
# 27  {0.0: 7, 17.05: 1, 21.09: 1, 19.79: 1, 23.27: ...
# 28  {0.0: 7, 17.05: 1, 21.09: 1, 19.79: 1, 23.27: ...
# 29      {0: 15, 2: 3, 1: 2, 29: 1, 4: 1, 12: 1, 9: 1}
# 30  {0: 2, 41: 2, 34: 1, 57: 1, 11: 1, 54: 1, 18: ...
# 31                                     {0: 23, 96: 1}
# 32  {'0': 9, '4,500': 2, '78': 1, '16,245': 1, '3,...
# 33  {'0': 11, '1,800': 2, '3,600': 2, '45': 1, '9,...
# 34     {'Conventional': 4, 'Organic': 4, 'Costco': 1}
# 35  {'Conventional Fairtrade Cavendish Banana': 4,...
# 36  {'Banane Cavendish Fairtrade Conventionelle': ...
# 37  {'Box with organic lid (purple and green)': 11...
# 38  {'Banano Cavendish Organic 3LB FairTrade with ...

# %%
import pandas as pd

df_port = pd.read_csv("Cleaned_data/Port_list.csv")
df_port
# Out:
#      Code                Name        Country Subdivision  Air Ocean Rail Road  \
# 0   USOLS             Nogales  United States         NaN   No    No   No  Yes
# 1   USGPT           Gulf Port  United States         NaN   No   Yes   No   No
# 2     TXA               Texas  United States          MD   No    No   No  Yes
# 3     TEX               Pharr  United States         NaN   No    No   No  Yes
# 4     SEA             Seattle  United States         NaN   No    No   No  Yes
# 5     PHL        Philadelphia  United States          PA  Yes   Yes   No   No
# 6     PHA               Pharr  United States         NaN   No    No   No  Yes
# 7      NY            New York  United States         NaN   No    No   No   No
# 8     NTD        Port Hueneme  United States          CA  Yes   Yes  Yes  Yes
# 9   NOGAL             Nogales  United States         NaN   No    No   No   No
# 10    ILG  Port of Wilmington  United States         NaN   No   Yes   No   No
# 11    HUE             Hueneme  United States          CA   No   Yes   No   No
# 12     HO             Houston  United States         NaN   No   Yes  Yes   No
# 13     AZ             Nogales  United States         NaN   No    No   No  Yes
# 14  00-95           San Diego  United States         NaN   No   Yes   No   No
# 15     00             Houston  United States         NaN   No   Yes  Yes   No
# 16    PAI               Paita           Peru         NaN   No   Yes   No   No
# 17    CIO             CORINTO      Nicaragua         NaN   No   Yes   No   No
# 18    CHI          Chinandega      Nicaragua         NaN   No   Yes   No  Yes
# 19    PBO      Puerto Bolivar        Ecuador           O   No   Yes   No   No
# 20    GYE           Guayaquil        Ecuador           G  Yes   Yes   No   No
# 21    SMR         Santa Marta       Colombia         NaN  Yes   Yes   No   No
# 22  VANCO           Vancouver         Canada         NaN   No    No   No   No
# 23    VAN           Vancouver         Canada         NaN   No    No   No   No
# 24    TOR             Toronto         Canada          ON  Yes   Yes   No  Yes
# 25    MTR            Montreal         Canada          QC   No   Yes   No  Yes
# 26     CG             Calgary         Canada         NaN   No    No   No   No
# 27    CAL             Calgary         Canada         NaN   No    No   No  Yes
# 28    000         Quebec City         Canada         NaN   No    No   No  Yes
# 29     00     Port of Halifax         Canada         NaN   No   Yes   No   No
#
#    Mail
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# 5   Yes
# 6    No
# 7    No
# 8    No
# 9    No
# 10   No
# 11   No
# 12   No
# 13   No
# 14   No
# 15   No
# 16   No
# 17   No
# 18   No
# 19   No
# 20  Yes
# 21   No
# 22   No
# 23   No
# 24  Yes
# 25   No
# 26   No
# 27   No
# 28   No
# 29   No

# %%
import pandas as pd
df=pd.read_csv("Cleaned_data/Commodity_list.csv")
df.head()
# Out:
#     Status  Job:Number Incoming Shipment:Name  \
# 0  Ordered      4637.0                    NaN
# 1  Ordered      4634.0                    NaN
# 2  Ordered      4631.0                    NaN
# 3  Ordered      4630.0                    NaN
# 4  Ordered      4633.0                    NaN
#
#                         Purchase Order:Seller Purchase Order:Carrier  \
# 0  Marplantis Organic Sustainable Agriculture                 Maersk
# 1            C.I. AGRICOLAS LAS FLORES S.A.S.          Dole Shipping
# 2                                 Latbio S.A.                 Maersk
# 3                   Hacienda Celia María C.A.                 Maersk
# 4            C.I. AGRICOLAS LAS FLORES S.A.S.               Seaboard
#
#   Purchase Order:Container# Purchase Order:Bill of Lading  \
# 0                       NaN                 MAEU249009979
# 1                       NaN                           NaN
# 2                       NaN                 MAEU248914945
# 3                       NaN                 MAEU248914871
# 4                       NaN                           NaN
#
#   Purchase Order:Harvest date Purchase Order:Departure Date  \
# 0                         NaN                    18/01/2025
# 1                         NaN                    25/01/2025
# 2                         NaN                    18/01/2025
# 3                         NaN                    18/01/2025
# 4                         NaN                    25/01/2025
#
#   Purchase Order:Arrival Date  ... Release Order Container Number  \
# 0                  03/02/2025  ...             0              NaN
# 1                  02/02/2025  ...             0              NaN
# 2                  03/02/2025  ...             0              NaN
# 3                  03/02/2025  ...             0              NaN
# 4                  04/02/2025  ...             0              NaN
#
#    Contained Item                                Manufacturer PO Line SO Line  \
# 0              No  Marplantis Organic Sustainable Agriculture       1       0
# 1              No            C.I. AGRICOLAS LAS FLORES S.A.S.       1       0
# 2              No                                 Latbio S.A.       1       0
# 3              No                   Hacienda Celia María C.A.       1       0
# 4              No            C.I. AGRICOLAS LAS FLORES S.A.S.       2       0
#
#    Lead Time Imported Warehouse Receipt Number Imported Pickup Order Number  \
# 0          0                               NaN                          NaN
# 1          0                               NaN                          NaN
# 2          0                               NaN                          NaN
# 3          0                               NaN                          NaN
# 4          0                               NaN                          NaN
#
#   Incoming Shipment:Notify Party
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 88 columns]

# %%
summary = []

for col in df.columns:
    unique_vals = df[col].unique()
    value_counts = df[col].value_counts().to_dict()
    summary.append({
        "column": col,
        "n_unique": len(unique_vals),
        "unique_values": unique_vals,
        "value_counts": value_counts
    })

df_summary = pd.DataFrame(summary)
df_summary
# Out:
#                      column  n_unique  \
# 0                    Status         2
# 1                    Number      2740
# 2                  Supplier        15
# 3                  Due Date       922
# 4                  Customer        23
# 5                    Income      1672
# 6                   Expense      2651
# 7                    Profit      2671
# 8   Customer:Account Number        15
# 9                      Date       350
# 10                 End Date       102
# 11                 Employee         8
# 12             Progress (%)        17
#
#                                         unique_values  \
# 0                                      [Open, Closed]
# 1   [4637, 4634, 4631, 4630, 4633, 4632, 4626, 462...
# 2   [Marplantis Organic Sustainable Agriculture, C...
# 3   [01/10/2025, 01/08/2025, 01/07/2025, 12/31/202...
# 4   [nan, Chiovitti Banana Co., Ltd, Costco US/Eas...
# 5   [0.00, 33,006.37, 32,632.96, 34,850.52, 33,768...
# 6   [18,337.05, 19,545.98, 0.00, 18,493.31, 19,268...
# 7   [-18,337.05, -19,545.98, 0.00, -18,493.31, -19...
# 8   [nan, C00004, C00007, C00029, C00024/001, C000...
# 9   [01/10/2025, 01/08/2025, 01/07/2025, 12/31/202...
# 10  [01/10/2025, 01/08/2025, 01/07/2025, 12/31/202...
# 11  [David Melo, Naomi Bendayan, Karyne Manseau, M...
# 12  [11, 44, 0, 66, 100, 55, 83, 77, 91, 88, 86, 9...
#
#                                          value_counts
# 0                       {'Closed': 2472, 'Open': 272}
# 1   {'4637': 1, '2771': 1, '2785': 1, '2789': 1, '...
# 2   {'ASOGUABO': 1050, 'C.I. AGRICOLAS LAS FLORES ...
# 3   {'11/22/2024': 21, '11/28/2024': 21, '11/06/20...
# 4   {'Costco Vaughan Wet': 409, 'Chiovitti Banana ...
# 5   {'0.00': 116, '31,680.00': 53, '34,780.80': 28...
# 6   {'0.00': 9, '23,107.84': 6, '23,043.94': 6, '1...
# 7   {'0.00': 9, '-23,043.94': 6, '-23,107.84': 6, ...
# 8   {'C00006/004': 409, 'C00004': 297, 'C00024/001...
# 9   {'03/24/2022': 27, '03/05/2024': 22, '08/13/20...
# 10  {'12/13/2024': 706, '11/09/2022': 487, '05/17/...
# 11  {'David Melo': 2372, 'Amandine Hance': 115, 'J...
# 12  {100: 2517, 44: 78, 11: 46, 83: 40, 66: 31, 0:...
